# %% [markdown]
# # 2012 Draft Class

# %%
from basketball_reference_scraper.players import get_game_logs
import pandas as pd

def is_numeric(value):
    try:
        float(value)
        return True
    except ValueError:
        return False

# List of players
players = [
    "Anthony Davis", "Michael Kidd-Gilchrist", "Bradley Beal", "Dion Waiters", 
    "Thomas Robinson", "Damian Lillard", "Harrison Barnes", "Terrence Ross", 
    "Andre Drummond", "Austin Rivers", "Meyers Leonard", "Jeremy Lamb", 
    "Kendall Marshall", "John Henson", "Maurice Harkless", "Royce White", 
    "Tyler Zeller", "Terrence Jones", "Andrew Nicholson", "Evan Fournier", 
    "Jared Sullinger", "Fab Melo", "John Jenkins", "Jared Cunningham", 
    "Tony Wroten", "Miles Plumlee", "Arnett Moultrie", "Perry Jones", 
    "Marquis Teague", "Festus Ezeli", "Jeff Taylor", "Tomáš Satoranský", 
    "Bernard James", "Jae Crowder", "Draymond Green", "Orlando Johnson", 
    "Quincy Acy", "Quincy Miller", "Khris Middleton", "Will Barton", 
    "Tyshawn Taylor", "Doron Lamb", "Mike Scott", "Kim English", 
    "Justin Hamilton", "Darius Miller", "Kevin Murphy", "Kostas Papanikolaou", 
    "Kyle O'Quinn", "İzzet Türkyılmaz", "Kris Joseph", "Ognjen Kuzmić", 
    "Furkan Aldemir", "Tornike Shengelia", "Darius Johnson-Odom", 
    "Tomislav Zubčić", "İlkan Karaman", "Robbie Hummel", "Marcus Denmon", 
    "Robert Sacre"
]

# Dictionaries to store total wins and total +/-
player_data = []

# Loop through each player to calculate total wins and cumulative +/-
for player in players:
    total_wins = 0
    total_plus_minus = 0
    data_missing = False  # Flag for missing data
    for year in [2013, 2014]:
        try:
            # Fetch game logs
            df = get_game_logs(player, year)
            # Calculate wins where PF is numeric and RESULT starts with 'W'
            wins = df[df['PF'].apply(is_numeric) & df['RESULT'].str.startswith('W')].shape[0]
            total_wins += wins
            
            # Ensure +/- column is numeric and calculate the sum
            df['+/-'] = pd.to_numeric(df['+/-'], errors='coerce')  # Convert +/- to numeric
            total_plus_minus += df['+/-'].sum(skipna=True)  # Add the sum for the year
        except Exception as e:
            print(f"Error processing {player} for {year}: {e}")
            data_missing = True
            break  # Exit the loop for this player if data is missing

    # Append data for the player
    if data_missing:
        player_data.append({
            'Player': player,
            'Wins': None,
            'Total +/-': None
        })
    else:
        player_data.append({
            'Player': player,
            'Wins': total_wins,
            'Total +/-': total_plus_minus
        })

# Create a DataFrame for the results
results_df = pd.DataFrame(player_data)

# Save the DataFrame to an Excel file
output_file = '2012_player_wins_plus_minus.xlsx'
results_df.to_excel(output_file, index=False)
print(f"Results saved to {output_file}")
# Out:
# You searched for "Anthony Davis"
# 9 results found.
# You searched for "Anthony Davis"
# 9 results found.
# You searched for "Michael Kidd-Gilchrist"
# 1 result found.
# Michael Kidd-Gilchrist
# Results for Michael Kidd-Gilchrist:
#
# Error processing Michael Kidd-Gilchrist for 2013: string index out of range
# You searched for "Bradley Beal"
# 1 result found.
# Bradley Beal
# Results for Bradley Beal:
#
# You searched for "Bradley Beal"
# 1 result found.
# Bradley Beal
# Results for Bradley Beal:
#
# You searched for "Dion Waiters"
# 1 result found.
# Dion Waiters
# Results for Dion Waiters:
#
# You searched for "Dion Waiters"
# 1 result found.
# Dion Waiters
# Results for Dion Waiters:
#
# You searched for "Thomas Robinson"
# 4 results found.
# You searched for "Thomas Robinson"
# 4 results found.
# You searched for "Damian Lillard"
# 1 result found.
# Damian Lillard
# Results for Damian Lillard:
#
# You searched for "Damian Lillard"
# 1 result found.
# Damian Lillard
# Results for Damian Lillard:
#
# You searched for "Harrison Barnes"
# 3 results found.
# You searched for "Harrison Barnes"
# 3 results found.
# You searched for "Terrence Ross"
# 2 results found.
# You searched for "Terrence Ross"
# 2 results found.
# You searched for "Andre Drummond"
# 1 result found.
# Andre Drummond
# Results for Andre Drummond:
#
# You searched for "Andre Drummond"
# 1 result found.
# Andre Drummond
# Results for Andre Drummond:
#
# You searched for "Austin Rivers"
# 1 result found.
# Austin Rivers
# Results for Austin Rivers:
#
# You searched for "Austin Rivers"
# 1 result found.
# Austin Rivers
# Results for Austin Rivers:
#
# You searched for "Meyers Leonard"
# 1 result found.
# Meyers Leonard
# Results for Meyers Leonard:
#
# You searched for "Meyers Leonard"
# 1 result found.
# Meyers Leonard
# Results for Meyers Leonard:
#
# You searched for "Jeremy Lamb"
# 6 results found.
# You searched for "Jeremy Lamb"
# 6 results found.
# You searched for "Kendall Marshall"
# 2 results found.
# You searched for "Kendall Marshall"
# 2 results found.
# You searched for "John Henson"
# 23 results found.
# You searched for "John Henson"
# 23 results found.
# You searched for "Maurice Harkless"
# 2 results found.
# You searched for "Maurice Harkless"
# 2 results found.
# You searched for "Royce White"
# 10 results found.
# You searched for "Royce White"
# 10 results found.
# You searched for "Tyler Zeller"
# 4 results found.
# You searched for "Tyler Zeller"
# 4 results found.
# You searched for "Terrence Jones"
# 3 results found.
# You searched for "Terrence Jones"
# 3 results found.
# You searched for "Andrew Nicholson"
# 1 result found.
# Andrew Nicholson
# Results for Andrew Nicholson:
#
# You searched for "Andrew Nicholson"
# 1 result found.
# Andrew Nicholson
# Results for Andrew Nicholson:
#
# You searched for "Evan Fournier"
# 2 results found.
# You searched for "Evan Fournier"
# 2 results found.
# You searched for "Jared Sullinger"
# 1 result found.
# Jared Sullinger
# Results for Jared Sullinger:
#
# You searched for "Jared Sullinger"
# 1 result found.
# Jared Sullinger
# Results for Jared Sullinger:
#
# You searched for "Fab Melo"
# 2 results found.
# You searched for "Fab Melo"
# 2 results found.
# Error processing Fab Melo for 2014: No tables found
# You searched for "John Jenkins"
# 5 results found.
# You searched for "John Jenkins"
# 5 results found.
# You searched for "Jared Cunningham"
# 2 results found.
# You searched for "Jared Cunningham"
# 2 results found.
# You searched for "Tony Wroten"
# 9 results found.
# You searched for "Tony Wroten"
# 9 results found.
# You searched for "Miles Plumlee"
# 2 results found.
# You searched for "Miles Plumlee"
# 2 results found.
# You searched for "Arnett Moultrie"
# 1 result found.
# Arnett Moultrie
# Results for Arnett Moultrie:
#
# You searched for "Arnett Moultrie"
# 1 result found.
# Arnett Moultrie
# Results for Arnett Moultrie:
#
# You searched for "Perry Jones"
# 22 results found.
# You searched for "Perry Jones"
# 22 results found.
# You searched for "Marquis Teague"
# 1 result found.
# Marquis Teague
# Results for Marquis Teague:
#
# You searched for "Marquis Teague"
# 1 result found.
# Marquis Teague
# Results for Marquis Teague:
#
# You searched for "Festus Ezeli"
# 1 result found.
# Festus Ezeli
# Results for Festus Ezeli:
#
# You searched for "Festus Ezeli"
# 1 result found.
# Festus Ezeli
# Results for Festus Ezeli:
#
# You searched for "Jeff Taylor"
# 11 results found.
# Error processing Jeff Taylor for 2013: No tables found
# You searched for "Tomáš Satoranský"
# 1 result found.
# Tomas Satoransky
# Results for Tomas Satoransky:
#
# Error processing Tomáš Satoranský for 2013: No tables found
# You searched for "Bernard James"
# 3 results found.
# You searched for "Bernard James"
# 3 results found.
# You searched for "Jae Crowder"
# 4 results found.
# You searched for "Jae Crowder"
# 4 results found.
# You searched for "Draymond Green"
# 2 results found.
# You searched for "Draymond Green"
# 2 results found.
# You searched for "Orlando Johnson"
# 3 results found.
# You searched for "Orlando Johnson"
# 3 results found.
# You searched for "Quincy Acy"
# 2 results found.
# You searched for "Quincy Acy"
# 2 results found.
# You searched for "Quincy Miller"
# 3 results found.
# You searched for "Quincy Miller"
# 3 results found.
# You searched for "Khris Middleton"
# 2 results found.
# You searched for "Khris Middleton"
# 2 results found.
# You searched for "Will Barton"
# 8 results found.
# You searched for "Will Barton"
# 8 results found.
# You searched for "Tyshawn Taylor"
# 1 result found.
# Tyshawn Taylor
# Results for Tyshawn Taylor:
#
# You searched for "Tyshawn Taylor"
# 1 result found.
# Tyshawn Taylor
# Results for Tyshawn Taylor:
#
# You searched for "Doron Lamb"
# 2 results found.
# You searched for "Doron Lamb"
# 2 results found.
# You searched for "Mike Scott"
# 22 results found.
# You searched for "Mike Scott"
# 22 results found.
# You searched for "Kim English"
# 3 results found.
# You searched for "Kim English"
# 3 results found.
# Error processing Kim English for 2014: No tables found
# You searched for "Justin Hamilton"
# 3 results found.
# Error processing Justin Hamilton for 2013: No tables found
# You searched for "Darius Miller"
# 7 results found.
# You searched for "Darius Miller"
# 7 results found.
# You searched for "Kevin Murphy"
# 9 results found.
# You searched for "Kevin Murphy"
# 9 results found.
# Error processing Kevin Murphy for 2014: No tables found
# You searched for "Kostas Papanikolaou"
# 1 result found.
# Kostas Papanikolaou
# Results for Kostas Papanikolaou:
#
# Error processing Kostas Papanikolaou for 2013: No tables found
# You searched for "Kyle O'Quinn"
# 1 result found.
# Kyle O'Quinn
# Results for Kyle O'Quinn:
#
# Error processing Kyle O'Quinn for 2013: string index out of range
# You searched for "İzzet Türkyılmaz"
# 0 results found.
# Error processing İzzet Türkyılmaz for 2013: 'NoneType' object has no attribute 'replace'
# You searched for "Kris Joseph"
# 4 results found.
# You searched for "Kris Joseph"
# 4 results found.
# Error processing Kris Joseph for 2014: No tables found
# You searched for "Ognjen Kuzmić"
# 1 result found.
# Ognjen Kuzmic
# Results for Ognjen Kuzmic:
#
# Error processing Ognjen Kuzmić for 2013: No tables found
# You searched for "Furkan Aldemir"
# 1 result found.
# Furkan Aldemir
# Results for Furkan Aldemir:
#
# Error processing Furkan Aldemir for 2013: No tables found
# You searched for "Tornike Shengelia"
# 1 result found.
# Tornike Shengelia
# Results for Tornike Shengelia:
#
# You searched for "Tornike Shengelia"
# 1 result found.
# Tornike Shengelia
# Results for Tornike Shengelia:
#
# You searched for "Darius Johnson-Odom"
# 1 result found.
# Darius Johnson-Odom
# Results for Darius Johnson-Odom:
#
# You searched for "Darius Johnson-Odom"
# 1 result found.
# Darius Johnson-Odom
# Results for Darius Johnson-Odom:
#
# You searched for "Tomislav Zubčić"
# 0 results found.
# Error processing Tomislav Zubčić for 2013: 'NoneType' object has no attribute 'replace'
# You searched for "İlkan Karaman"
# 0 results found.
# Error processing İlkan Karaman for 2013: 'NoneType' object has no attribute 'replace'
# You searched for "Robbie Hummel"
# 1 result found.
# Robbie Hummel
# Results for Robbie Hummel:
#
# Error processing Robbie Hummel for 2013: No tables found
# You searched for "Marcus Denmon"
# 0 results found.
# Error processing Marcus Denmon for 2013: 'NoneType' object has no attribute 'replace'
# You searched for "Robert Sacre"
# 8 results found.
# You searched for "Robert Sacre"
# 8 results found.
# Results saved to 2012_player_wins_plus_minus.xlsx

# %% [markdown]
# # 2013 Draft Class

# %%
from basketball_reference_scraper.players import get_game_logs
import pandas as pd

def is_numeric(value):
    try:
        float(value)
        return True
    except ValueError:
        return False

# List of players
players = [
    "Anthony Bennett",
    "Victor Oladipo",
    "Otto Porter Jr.",
    "Cody Zeller",
    "Alex Len",
    "Nerlens Noel",
    "Ben McLemore",
    "Kentavious Caldwell-Pope",
    "Trey Burke",
    "CJ McCollum",
    "Michael Carter-Williams",
    "Steven Adams",
    "Kelly Olynyk",
    "Shabazz Muhammad",
    "Giannis Antetokounmpo",
    "Lucas Nogueira",
    "Dennis Schröder",
    "Shane Larkin",
    "Sergey Karasev",
    "Tony Snell",
    "Gorgui Dieng",
    "Mason Plumlee",
    "Solomon Hill",
    "Tim Hardaway Jr.",
    "Reggie Bullock",
    "Andre Roberson",
    "Rudy Gobert",
    "Livio Jean-Charles",
    "Archie Goodwin",
    "Nemanja Nedović",
    "Allen Crabbe",
    "Álex Abrines",
    "Carrick Felix",
    "Isaiah Canaan",
    "Glen Rice Jr.",
    "Ray McCallum",
    "Tony Mitchell",
    "Nate Wolters",
    "Jeff Withey",
    "Grant Jerrett",
    "Jamaal Franklin",
    "Pierre Jackson",
    "Ricky Ledo",
    "Mike Muscala",
    "Marko Todorović",
    "Erick Green",
    "Raul Neto",
    "Ryan Kelly",
    "Erik Murphy",
    "James Ennis III",
    "Romero Osby",
    "Lorenzo Brown",
    "Colton Iverson",
    "Arsalan Kazemi",
    "Joffrey Lauvergne",
    "Peyton Siva",
    "Alex Oriakhi",
    "Deshaun Thomas",
    "Bojan Dubljević",
    "Jānis Timma"
]

# Dictionaries to store total wins and total +/-
player_data = []

# Loop through each player to calculate total wins and cumulative +/-
for player in players:
    total_wins = 0
    total_plus_minus = 0
    data_missing = False  # Flag for missing data
    for year in [2014, 2015]:
        try:
            # Fetch game logs
            df = get_game_logs(player, year)
            # Calculate wins where PF is numeric and RESULT starts with 'W'
            wins = df[df['PF'].apply(is_numeric) & df['RESULT'].str.startswith('W')].shape[0]
            total_wins += wins
            
            # Ensure +/- column is numeric and calculate the sum
            df['+/-'] = pd.to_numeric(df['+/-'], errors='coerce')  # Convert +/- to numeric
            total_plus_minus += df['+/-'].sum(skipna=True)  # Add the sum for the year
        except Exception as e:
            print(f"Error processing {player} for {year}: {e}")
            data_missing = True
            break  # Exit the loop for this player if data is missing

    # Append data for the player
    if data_missing:
        player_data.append({
            'Player': player,
            'Wins': None,
            'Total +/-': None
        })
    else:
        player_data.append({
            'Player': player,
            'Wins': total_wins,
            'Total +/-': total_plus_minus
        })

# Create a DataFrame for the results
results_df = pd.DataFrame(player_data)

# Save the DataFrame to an Excel file
output_file = '2013_player_wins_plus_minus.xlsx'
results_df.to_excel(output_file, index=False)
print(f"Results saved to {output_file}")
# Out:
# You searched for "Anthony Bennett"
# 3 results found.
# You searched for "Anthony Bennett"
# 3 results found.
# You searched for "Victor Oladipo"
# 1 result found.
# Victor Oladipo
# Results for Victor Oladipo:
#
# You searched for "Victor Oladipo"
# 1 result found.
# Victor Oladipo
# Results for Victor Oladipo:
#
# You searched for "Otto Porter Jr."
# 1 result found.
# Otto Porter
# Results for Otto Porter:
#
# You searched for "Otto Porter Jr."
# 1 result found.
# Otto Porter
# Results for Otto Porter:
#
# You searched for "Cody Zeller"
# 8 results found.
# You searched for "Cody Zeller"
# 8 results found.
# You searched for "Alex Len"
# 7 results found.
# You searched for "Alex Len"
# 7 results found.
# You searched for "Nerlens Noel"
# 1 result found.
# Nerlens Noel
# Results for Nerlens Noel:
#
# You searched for "Nerlens Noel"
# 1 result found.
# Nerlens Noel
# Results for Nerlens Noel:
#
# You searched for "Ben McLemore"
# 3 results found.
# You searched for "Ben McLemore"
# 3 results found.
# You searched for "Kentavious Caldwell-Pope"
# 1 result found.
# Kentavious Caldwell-Pope
# Results for Kentavious Caldwell-Pope:
#
# You searched for "Kentavious Caldwell-Pope"
# 1 result found.
# Kentavious Caldwell-Pope
# Results for Kentavious Caldwell-Pope:
#
# You searched for "Trey Burke"
# 5 results found.
# You searched for "Trey Burke"
# 5 results found.
# You searched for "CJ McCollum"
# 2 results found.
# You searched for "CJ McCollum"
# 2 results found.
# You searched for "Michael Carter-Williams"
# 1 result found.
# Michael Carter-Williams
# Results for Michael Carter-Williams:
#
# You searched for "Michael Carter-Williams"
# 1 result found.
# Michael Carter-Williams
# Results for Michael Carter-Williams:
#
# You searched for "Steven Adams"
# 6 results found.
# You searched for "Steven Adams"
# 6 results found.
# You searched for "Kelly Olynyk"
# 1 result found.
# Kelly Olynyk
# Results for Kelly Olynyk:
#
# You searched for "Kelly Olynyk"
# 1 result found.
# Kelly Olynyk
# Results for Kelly Olynyk:
#
# You searched for "Shabazz Muhammad"
# 1 result found.
# Shabazz Muhammad
# Results for Shabazz Muhammad:
#
# You searched for "Shabazz Muhammad"
# 1 result found.
# Shabazz Muhammad
# Results for Shabazz Muhammad:
#
# You searched for "Giannis Antetokounmpo"
# 2 results found.
# You searched for "Giannis Antetokounmpo"
# 2 results found.
# You searched for "Lucas Nogueira"
# 1 result found.
# Lucas Nogueira
# Results for Lucas Nogueira:
#
# Error processing Lucas Nogueira for 2014: No tables found
# You searched for "Dennis Schröder"
# 1 result found.
# Dennis Schroder
# Results for Dennis Schroder:
#
# You searched for "Dennis Schröder"
# 1 result found.
# Dennis Schroder
# Results for Dennis Schroder:
#
# You searched for "Shane Larkin"
# 1 result found.
# Shane Larkin
# Results for Shane Larkin:
#
# You searched for "Shane Larkin"
# 1 result found.
# Shane Larkin
# Results for Shane Larkin:
#
# You searched for "Sergey Karasev"
# 1 result found.
# Sergey Karasev
# Results for Sergey Karasev:
#
# You searched for "Sergey Karasev"
# 1 result found.
# Sergey Karasev
# Results for Sergey Karasev:
#
# You searched for "Tony Snell"
# 16 results found.
# You searched for "Tony Snell"
# 16 results found.
# You searched for "Gorgui Dieng"
# 1 result found.
# Gorgui Dieng
# Results for Gorgui Dieng:
#
# You searched for "Gorgui Dieng"
# 1 result found.
# Gorgui Dieng
# Results for Gorgui Dieng:
#
# You searched for "Mason Plumlee"
# 2 results found.
# You searched for "Mason Plumlee"
# 2 results found.
# You searched for "Solomon Hill"
# 2 results found.
# You searched for "Solomon Hill"
# 2 results found.
# You searched for "Tim Hardaway Jr."
# 2 results found.
# Error processing Tim Hardaway Jr. for 2014: No tables found
# You searched for "Reggie Bullock"
# 1 result found.
# Reggie Bullock
# Results for Reggie Bullock:
#
# You searched for "Reggie Bullock"
# 1 result found.
# Reggie Bullock
# Results for Reggie Bullock:
#
# You searched for "Andre Roberson"
# 2 results found.
# You searched for "Andre Roberson"
# 2 results found.
# You searched for "Rudy Gobert"
# 2 results found.
# You searched for "Rudy Gobert"
# 2 results found.
# You searched for "Livio Jean-Charles"
# 0 results found.
# Error processing Livio Jean-Charles for 2014: 'NoneType' object has no attribute 'replace'
# You searched for "Archie Goodwin"
# 1 result found.
# Archie Goodwin
# Results for Archie Goodwin:
#
# You searched for "Archie Goodwin"
# 1 result found.
# Archie Goodwin
# Results for Archie Goodwin:
#
# You searched for "Nemanja Nedović"
# 1 result found.
# Nemanja Nedovic
# Results for Nemanja Nedovic:
#
# You searched for "Nemanja Nedović"
# 1 result found.
# Nemanja Nedovic
# Results for Nemanja Nedovic:
#
# You searched for "Allen Crabbe"
# 1 result found.
# Allen Crabbe
# Results for Allen Crabbe:
#
# You searched for "Allen Crabbe"
# 1 result found.
# Allen Crabbe
# Results for Allen Crabbe:
#
# You searched for "Álex Abrines"
# 1 result found.
# Alex Abrines
# Results for Alex Abrines:
#
# Error processing Álex Abrines for 2014: No tables found
# You searched for "Carrick Felix"
# 1 result found.
# Carrick Felix
# Results for Carrick Felix:
#
# You searched for "Carrick Felix"
# 1 result found.
# Carrick Felix
# Results for Carrick Felix:
#
# Error processing Carrick Felix for 2015: No tables found
# You searched for "Isaiah Canaan"
# 1 result found.
# Isaiah Canaan
# Results for Isaiah Canaan:
#
# You searched for "Isaiah Canaan"
# 1 result found.
# Isaiah Canaan
# Results for Isaiah Canaan:
#
# You searched for "Glen Rice Jr."
# 2 results found.
# Error processing Glen Rice Jr. for 2014: No tables found
# You searched for "Ray McCallum"
# 2 results found.
# You searched for "Ray McCallum"
# 2 results found.
# You searched for "Tony Mitchell"
# 5 results found.
# You searched for "Tony Mitchell"
# 5 results found.
# You searched for "Nate Wolters"
# 1 result found.
# Nate Wolters
# Results for Nate Wolters:
#
# You searched for "Nate Wolters"
# 1 result found.
# Nate Wolters
# Results for Nate Wolters:
#
# You searched for "Jeff Withey"
# 2 results found.
# You searched for "Jeff Withey"
# 2 results found.
# You searched for "Grant Jerrett"
# 1 result found.
# Grant Jerrett
# Results for Grant Jerrett:
#
# You searched for "Grant Jerrett"
# 1 result found.
# Grant Jerrett
# Results for Grant Jerrett:
#
# You searched for "Jamaal Franklin"
# 1 result found.
# Jamaal Franklin
# Results for Jamaal Franklin:
#
# You searched for "Jamaal Franklin"
# 1 result found.
# Jamaal Franklin
# Results for Jamaal Franklin:
#
# You searched for "Pierre Jackson"
# 2 results found.
# Error processing Pierre Jackson for 2014: No tables found
# You searched for "Ricky Ledo"
# 7 results found.
# You searched for "Ricky Ledo"
# 7 results found.
# You searched for "Mike Muscala"
# 2 results found.
# You searched for "Mike Muscala"
# 2 results found.
# You searched for "Marko Todorović"
# 2 results found.
# Error processing Marko Todorović for 2014: No tables found
# You searched for "Erick Green"
# 11 results found.
# Error processing Erick Green for 2014: No tables found
# You searched for "Raul Neto"
# 7 results found.
# Error processing Raul Neto for 2014: No tables found
# You searched for "Ryan Kelly"
# 8 results found.
# You searched for "Ryan Kelly"
# 8 results found.
# You searched for "Erik Murphy"
# 8 results found.
# You searched for "Erik Murphy"
# 8 results found.
# Error processing Erik Murphy for 2015: No tables found
# You searched for "James Ennis III"
# 1 result found.
# James Ennis
# Results for James Ennis:
#
# Error processing James Ennis III for 2014: No tables found
# You searched for "Romero Osby"
# 0 results found.
# Error processing Romero Osby for 2014: 'NoneType' object has no attribute 'replace'
# You searched for "Lorenzo Brown"
# 2 results found.
# You searched for "Lorenzo Brown"
# 2 results found.
# You searched for "Colton Iverson"
# 1 result found.
# Allen Iverson
# Results for Allen Iverson:
#
# Error processing Colton Iverson for 2014: No tables found
# You searched for "Arsalan Kazemi"
# 0 results found.
# Error processing Arsalan Kazemi for 2014: 'NoneType' object has no attribute 'replace'
# You searched for "Joffrey Lauvergne"
# 1 result found.
# Joffrey Lauvergne
# Results for Joffrey Lauvergne:
#
# Error processing Joffrey Lauvergne for 2014: No tables found
# You searched for "Peyton Siva"
# 1 result found.
# Peyton Siva
# Results for Peyton Siva:
#
# You searched for "Peyton Siva"
# 1 result found.
# Peyton Siva
# Results for Peyton Siva:
#
# Error processing Peyton Siva for 2015: No tables found
# You searched for "Alex Oriakhi"
# 0 results found.
# Error processing Alex Oriakhi for 2014: 'NoneType' object has no attribute 'replace'
# You searched for "Deshaun Thomas"
# 1 result found.
# Etan Thomas
# Results for Etan Thomas:
# Error processing Deshaun Thomas for 2014: No tables found
# You searched for "Bojan Dubljević"
# 0 results found.
# Error processing Bojan Dubljević for 2014: 'NoneType' object has no attribute 'replace'
# You searched for "Jānis Timma"
# 1 result found.
# Dan Tieman
# Results for Dan Tieman:
#
# Error processing Jānis Timma for 2014: No tables found
# Results saved to 2013_player_wins_plus_minus.xlsx

# %% [markdown]
# # 2014 Draft Class

# %%
from basketball_reference_scraper.players import get_game_logs
import pandas as pd

def is_numeric(value):
    try:
        float(value)
        return True
    except ValueError:
        return False

# List of players
players = [
    "Andrew Wiggins",
    "Jabari Parker",
    "Joel Embiid",
    "Aaron Gordon",
    "Dante Exum",
    "Marcus Smart",
    "Julius Randle",
    "Nik Stauskas",
    "Noah Vonleh",
    "Elfrid Payton",
    "Doug McDermott",
    "Dario Šarić",
    "Zach LaVine",
    "T.J. Warren",
    "Adreian Payne",
    "Jusuf Nurkić",
    "James Young",
    "Tyler Ennis",
    "Gary Harris",
    "Bruno Caboclo",
    "Mitch McGary",
    "Jordan Adams",
    "Rodney Hood",
    "Shabazz Napier",
    "Clint Capela",
    "P.J. Hairston",
    "Bogdan Bogdanović",
    "C.J. Wilcox",
    "Josh Huestis",
    "Kyle Anderson",
    "Damien Inglis",
    "K.J. McDaniels",
    "Joe Harris",
    "Cleanthony Early",
    "Jarnell Stokes",
    "Johnny O'Bryant",
    "DeAndre Daniels",
    "Spencer Dinwiddie",
    "Jerami Grant",
    "Glenn Robinson III",
    "Nikola Jokić",
    "Nick Johnson",
    "Edy Tavares",
    "Markel Brown",
    "Dwight Powell",
    "Jordan Clarkson",
    "Russ Smith",
    "Lamar Patterson",
    "Cameron Bairstow",
    "Alec Brown",
    "Thanasis Antetokounmpo",
    "Vasilije Micić",
    "Alessandro Gentile",
    "Nemanja Dangubić",
    "Semaj Christon",
    "Devyn Marble",
    "Louis Labeyrie",
    "Jordan McRae",
    "Xavier Thames",
    "Cory Jefferson"
]


# Dictionaries to store total wins and total +/-
player_data = []

# Loop through each player to calculate total wins and cumulative +/-
for player in players:
    total_wins = 0
    total_plus_minus = 0
    data_missing = False  # Flag for missing data
    for year in [2015, 2016]:
        try:
            # Fetch game logs
            df = get_game_logs(player, year)
            # Calculate wins where PF is numeric and RESULT starts with 'W'
            wins = df[df['PF'].apply(is_numeric) & df['RESULT'].str.startswith('W')].shape[0]
            total_wins += wins
            
            # Ensure +/- column is numeric and calculate the sum
            df['+/-'] = pd.to_numeric(df['+/-'], errors='coerce')  # Convert +/- to numeric
            total_plus_minus += df['+/-'].sum(skipna=True)  # Add the sum for the year
        except Exception as e:
            print(f"Error processing {player} for {year}: {e}")
            data_missing = True
            break  # Exit the loop for this player if data is missing

    # Append data for the player
    if data_missing:
        player_data.append({
            'Player': player,
            'Wins': None,
            'Total +/-': None
        })
    else:
        player_data.append({
            'Player': player,
            'Wins': total_wins,
            'Total +/-': total_plus_minus
        })

# Create a DataFrame for the results
results_df = pd.DataFrame(player_data)

# Save the DataFrame to an Excel file
output_file = '2014_player_wins_plus_minus.xlsx'
results_df.to_excel(output_file, index=False)
print(f"Results saved to {output_file}")
# Out:
# You searched for "Andrew Wiggins"
# 2 results found.
# You searched for "Andrew Wiggins"
# 2 results found.
# You searched for "Jabari Parker"
# 1 result found.
# Jabari Parker
# Results for Jabari Parker:
#
# You searched for "Jabari Parker"
# 1 result found.
# Jabari Parker
# Results for Jabari Parker:
#
# You searched for "Joel Embiid"
# 1 result found.
# Joel Embiid
# Results for Joel Embiid:
#
# You searched for "Joel Embiid"
# 1 result found.
# Joel Embiid
# Results for Joel Embiid:
#
# You searched for "Aaron Gordon"
# 6 results found.
# You searched for "Aaron Gordon"
# 6 results found.
# You searched for "Dante Exum"
# 1 result found.
# Dante Exum
# Results for Dante Exum:
#
# You searched for "Dante Exum"
# 1 result found.
# Dante Exum
# Results for Dante Exum:
#
# You searched for "Marcus Smart"
# 4 results found.
# You searched for "Marcus Smart"
# 4 results found.
# You searched for "Julius Randle"
# 3 results found.
# You searched for "Julius Randle"
# 3 results found.
# You searched for "Nik Stauskas"
# 1 result found.
# Nik Stauskas
# Results for Nik Stauskas:
#
# You searched for "Nik Stauskas"
# 1 result found.
# Nik Stauskas
# Results for Nik Stauskas:
#
# You searched for "Noah Vonleh"
# 1 result found.
# Noah Vonleh
# Results for Noah Vonleh:
#
# You searched for "Noah Vonleh"
# 1 result found.
# Noah Vonleh
# Results for Noah Vonleh:
#
# You searched for "Elfrid Payton"
# 1 result found.
# Elfrid Payton
# Results for Elfrid Payton:
#
# You searched for "Elfrid Payton"
# 1 result found.
# Elfrid Payton
# Results for Elfrid Payton:
#
# You searched for "Doug McDermott"
# 2 results found.
# You searched for "Doug McDermott"
# 2 results found.
# You searched for "Dario Šarić"
# 2 results found.
# Error processing Dario Šarić for 2015: No tables found
# You searched for "Zach LaVine"
# 3 results found.
# You searched for "Zach LaVine"
# 3 results found.
# You searched for "T.J. Warren"
# 5 results found.
# Error processing T.J. Warren for 2015: string index out of range
# You searched for "Adreian Payne"
# 1 result found.
# Adreian Payne
# Results for Adreian Payne:
#
# You searched for "Adreian Payne"
# 1 result found.
# Adreian Payne
# Results for Adreian Payne:
#
# You searched for "Jusuf Nurkić"
# 1 result found.
# Jusuf Nurkic
# Results for Jusuf Nurkic:
#
# You searched for "Jusuf Nurkić"
# 1 result found.
# Jusuf Nurkic
# Results for Jusuf Nurkic:
#
# You searched for "James Young"
# 12 results found.
# You searched for "James Young"
# 12 results found.
# You searched for "Tyler Ennis"
# 6 results found.
# You searched for "Tyler Ennis"
# 6 results found.
# You searched for "Gary Harris"
# 14 results found.
# You searched for "Gary Harris"
# 14 results found.
# You searched for "Bruno Caboclo"
# 1 result found.
# Bruno Caboclo
# Results for Bruno Caboclo:
#
# You searched for "Bruno Caboclo"
# 1 result found.
# Bruno Caboclo
# Results for Bruno Caboclo:
#
# You searched for "Mitch McGary"
# 2 results found.
# You searched for "Mitch McGary"
# 2 results found.
# You searched for "Jordan Adams"
# 8 results found.
# You searched for "Jordan Adams"
# 8 results found.
# You searched for "Rodney Hood"
# 4 results found.
# You searched for "Rodney Hood"
# 4 results found.
# You searched for "Shabazz Napier"
# 1 result found.
# Shabazz Napier
# Results for Shabazz Napier:
#
# You searched for "Shabazz Napier"
# 1 result found.
# Shabazz Napier
# Results for Shabazz Napier:
#
# You searched for "Clint Capela"
# 3 results found.
# Error processing Clint Capela for 2015: string index out of range
# You searched for "P.J. Hairston"
# 3 results found.
# Error processing P.J. Hairston for 2015: string index out of range
# You searched for "Bogdan Bogdanović"
# 2 results found.
# Error processing Bogdan Bogdanović for 2015: No tables found
# You searched for "C.J. Wilcox"
# 5 results found.
# Error processing C.J. Wilcox for 2015: string index out of range
# You searched for "Josh Huestis"
# 1 result found.
# Josh Huestis
# Results for Josh Huestis:
#
# Error processing Josh Huestis for 2015: No tables found
# You searched for "Kyle Anderson"
# 16 results found.
# You searched for "Kyle Anderson"
# 16 results found.
# You searched for "Damien Inglis"
# 1 result found.
# Damien Inglis
# Results for Damien Inglis:
#
# You searched for "Damien Inglis"
# 1 result found.
# Damien Inglis
# Results for Damien Inglis:
#
# You searched for "K.J. McDaniels"
# 2 results found.
# Error processing K.J. McDaniels for 2015: string index out of range
# You searched for "Joe Harris"
# 20 results found.
# You searched for "Joe Harris"
# 20 results found.
# You searched for "Cleanthony Early"
# 1 result found.
# Cleanthony Early
# Results for Cleanthony Early:
#
# You searched for "Cleanthony Early"
# 1 result found.
# Cleanthony Early
# Results for Cleanthony Early:
#
# You searched for "Jarnell Stokes"
# 1 result found.
# Jarnell Stokes
# Results for Jarnell Stokes:
#
# You searched for "Jarnell Stokes"
# 1 result found.
# Jarnell Stokes
# Results for Jarnell Stokes:
#
# You searched for "Johnny O'Bryant"
# 1 result found.
# Johnny O'Bryant
# Results for Johnny O'Bryant:
#
# Error processing Johnny O'Bryant for 2015: string index out of range
# You searched for "DeAndre Daniels"
# 0 results found.
# Error processing DeAndre Daniels for 2015: 'NoneType' object has no attribute 'replace'
# You searched for "Spencer Dinwiddie"
# 1 result found.
# Spencer Dinwiddie
# Results for Spencer Dinwiddie:
#
# You searched for "Spencer Dinwiddie"
# 1 result found.
# Spencer Dinwiddie
# Results for Spencer Dinwiddie:
#
# You searched for "Jerami Grant"
# 4 results found.
# You searched for "Jerami Grant"
# 4 results found.
# You searched for "Glenn Robinson III"
# 2 results found.
# Error processing Glenn Robinson III for 2015: No tables found
# You searched for "Nikola Jokić"
# 3 results found.
# Error processing Nikola Jokić for 2015: No tables found
# You searched for "Nick Johnson"
# 32 results found.
# You searched for "Nick Johnson"
# 32 results found.
# Error processing Nick Johnson for 2016: No tables found
# You searched for "Edy Tavares"
# 1 result found.
# Edy Tavares
# Results for Edy Tavares:
#
# Error processing Edy Tavares for 2015: string index out of range
# You searched for "Markel Brown"
# 14 results found.
# You searched for "Markel Brown"
# 14 results found.
# You searched for "Dwight Powell"
# 3 results found.
# You searched for "Dwight Powell"
# 3 results found.
# You searched for "Jordan Clarkson"
# 1 result found.
# Jordan Clarkson
# Results for Jordan Clarkson:
#
# You searched for "Jordan Clarkson"
# 1 result found.
# Jordan Clarkson
# Results for Jordan Clarkson:
#
# You searched for "Russ Smith"
# 31 results found.
# You searched for "Russ Smith"
# 31 results found.
# You searched for "Lamar Patterson"
# 2 results found.
# Error processing Lamar Patterson for 2015: No tables found
# You searched for "Cameron Bairstow"
# 1 result found.
# Cameron Bairstow
# Results for Cameron Bairstow:
#
# You searched for "Cameron Bairstow"
# 1 result found.
# Cameron Bairstow
# Results for Cameron Bairstow:
#
# You searched for "Alec Brown"
# 24 results found.
# Error processing Alec Brown for 2015: No tables found
# You searched for "Thanasis Antetokounmpo"
# 2 results found.
# Error processing Thanasis Antetokounmpo for 2015: No tables found
# You searched for "Vasilije Micić"
# 0 results found.
# Error processing Vasilije Micić for 2015: 'NoneType' object has no attribute 'replace'
# You searched for "Alessandro Gentile"
# 0 results found.
# Error processing Alessandro Gentile for 2015: 'NoneType' object has no attribute 'replace'
# You searched for "Nemanja Dangubić"
# 0 results found.
# Error processing Nemanja Dangubić for 2015: 'NoneType' object has no attribute 'replace'
# You searched for "Semaj Christon"
# 1 result found.
# Semaj Christon
# Results for Semaj Christon:
#
# Error processing Semaj Christon for 2015: No tables found
# You searched for "Devyn Marble"
# 4 results found.
# You searched for "Devyn Marble"
# 4 results found.
# You searched for "Louis Labeyrie"
# 0 results found.
# Error processing Louis Labeyrie for 2015: 'NoneType' object has no attribute 'replace'
# You searched for "Jordan McRae"
# 9 results found.
# Error processing Jordan McRae for 2015: No tables found
# You searched for "Xavier Thames"
# 1 result found.
# Xavier Henry
# Results for Xavier Henry:
#
# You searched for "Xavier Thames"
# 1 result found.
# Xavier Henry
# Results for Xavier Henry:
#
# Error processing Xavier Thames for 2016: No tables found
# You searched for "Cory Jefferson"
# 2 results found.
# You searched for "Cory Jefferson"
# 2 results found.
# Results saved to 2014_player_wins_plus_minus.xlsx

# %% [markdown]
# # 2015 Class

# %%
from basketball_reference_scraper.players import get_game_logs
import pandas as pd

def is_numeric(value):
    try:
        float(value)
        return True
    except ValueError:
        return False

# List of players
players = [
    "Karl-Anthony Towns",
    "D'Angelo Russell",
    "Jahlil Okafor",
    "Kristaps Porzingis",
    "Mario Hezonja",
    "Willie Cauley-Stein",
    "Emmanuel Mudiay",
    "Stanley Johnson",
    "Frank Kaminsky",
    "Justise Winslow",
    "Myles Turner",
    "Trey Lyles",
    "Devin Booker",
    "Cameron Payne",
    "Kelly Oubre Jr.",
    "Terry Rozier",
    "Rashad Vaughn",
    "Sam Dekker",
    "Jerian Grant",
    "Delon Wright",
    "Justin Anderson",
    "Bobby Portis",
    "Rondae Hollis-Jefferson",
    "Tyus Jones",
    "Jarell Martin",
    "Nikola Milutinov",
    "Larry Nance Jr.",
    "R.J. Hunter",
    "Chris McCullough",
    "Kevon Looney",
    "Cedi Osman",
    "Montrezl Harrell",
    "Jordan Mickey",
    "Anthony Brown",
    "Willy Hernangómez",
    "Rakeem Christmas",
    "Richaun Holmes",
    "Darrun Hilliard",
    "Juan Pablo Vaulet",
    "Josh Richardson",
    "Pat Connaughton",
    "Olivier Hanlan",
    "Joe Young",
    "Andrew Harrison",
    "Marcus Thornton",
    "Norman Powell",
    "Artūras Gudaitis",
    "Dakari Johnson",
    "Aaron White",
    "Marcus Eriksson",
    "Tyler Harvey",
    "Satnam Singh",
    "Sir'Dominic Pointer",
    "Dani Díez",
    "Cady Lalanne",
    "Branden Dawson",
    "Nikola Radičević",
    "J.P. Tokoto",
    "Dimitrios Agravanis",
    "Luka Mitrović"
]


# Dictionaries to store total wins and total +/-
player_data = []

# Loop through each player to calculate total wins and cumulative +/-
for player in players:
    total_wins = 0
    total_plus_minus = 0
    data_missing = False  # Flag for missing data
    for year in [2016, 2017]:
        try:
            # Fetch game logs
            df = get_game_logs(player, year)
            # Calculate wins where PF is numeric and RESULT starts with 'W'
            wins = df[df['PF'].apply(is_numeric) & df['RESULT'].str.startswith('W')].shape[0]
            total_wins += wins
            
            # Ensure +/- column is numeric and calculate the sum
            df['+/-'] = pd.to_numeric(df['+/-'], errors='coerce')  # Convert +/- to numeric
            total_plus_minus += df['+/-'].sum(skipna=True)  # Add the sum for the year
        except Exception as e:
            print(f"Error processing {player} for {year}: {e}")
            data_missing = True
            break  # Exit the loop for this player if data is missing

    # Append data for the player
    if data_missing:
        player_data.append({
            'Player': player,
            'Wins': None,
            'Total +/-': None
        })
    else:
        player_data.append({
            'Player': player,
            'Wins': total_wins,
            'Total +/-': total_plus_minus
        })

# Create a DataFrame for the results
results_df = pd.DataFrame(player_data)

# Save the DataFrame to an Excel file
output_file = '2015_player_wins_plus_minus.xlsx'
results_df.to_excel(output_file, index=False)
print(f"Results saved to {output_file}")
# Out:
# You searched for "Karl-Anthony Towns"
# 1 result found.
# Karl-Anthony Towns
# Results for Karl-Anthony Towns:
#
# You searched for "Karl-Anthony Towns"
# 1 result found.
# Karl-Anthony Towns
# Results for Karl-Anthony Towns:
#
# You searched for "D'Angelo Russell"
# 1 result found.
# D'Angelo Russell
# Results for D'Angelo Russell:
#
# Error processing D'Angelo Russell for 2016: string index out of range
# You searched for "Jahlil Okafor"
# 1 result found.
# Jahlil Okafor
# Results for Jahlil Okafor:
#
# You searched for "Jahlil Okafor"
# 1 result found.
# Jahlil Okafor
# Results for Jahlil Okafor:
#
# You searched for "Kristaps Porzingis"
# 1 result found.
# Kristaps Porzingis
# Results for Kristaps Porzingis:
#
# You searched for "Kristaps Porzingis"
# 1 result found.
# Kristaps Porzingis
# Results for Kristaps Porzingis:
#
# You searched for "Mario Hezonja"
# 1 result found.
# Mario Hezonja
# Results for Mario Hezonja:
#
# You searched for "Mario Hezonja"
# 1 result found.
# Mario Hezonja
# Results for Mario Hezonja:
#
# You searched for "Willie Cauley-Stein"
# 1 result found.
# Willie Cauley-Stein
# Results for Willie Cauley-Stein:
#
# You searched for "Willie Cauley-Stein"
# 1 result found.
# Willie Cauley-Stein
# Results for Willie Cauley-Stein:
#
# You searched for "Emmanuel Mudiay"
# 1 result found.
# Emmanuel Mudiay
# Results for Emmanuel Mudiay:
#
# You searched for "Emmanuel Mudiay"
# 1 result found.
# Emmanuel Mudiay
# Results for Emmanuel Mudiay:
#
# You searched for "Stanley Johnson"
# 9 results found.
# You searched for "Stanley Johnson"
# 9 results found.
# You searched for "Frank Kaminsky"
# 2 results found.
# You searched for "Frank Kaminsky"
# 2 results found.
# You searched for "Justise Winslow"
# 1 result found.
# Justise Winslow
# Results for Justise Winslow:
#
# You searched for "Justise Winslow"
# 1 result found.
# Justise Winslow
# Results for Justise Winslow:
#
# You searched for "Myles Turner"
# 3 results found.
# You searched for "Myles Turner"
# 3 results found.
# You searched for "Trey Lyles"
# 5 results found.
# You searched for "Trey Lyles"
# 5 results found.
# You searched for "Devin Booker"
# 11 results found.
# You searched for "Devin Booker"
# 11 results found.
# You searched for "Cameron Payne"
# 2 results found.
# You searched for "Cameron Payne"
# 2 results found.
# You searched for "Kelly Oubre Jr."
# 1 result found.
# Kelly Oubre
# Results for Kelly Oubre:
#
# You searched for "Kelly Oubre Jr."
# 1 result found.
# Kelly Oubre
# Results for Kelly Oubre:
#
# You searched for "Terry Rozier"
# 9 results found.
# You searched for "Terry Rozier"
# 9 results found.
# You searched for "Rashad Vaughn"
# 3 results found.
# You searched for "Rashad Vaughn"
# 3 results found.
# You searched for "Sam Dekker"
# 1 result found.
# Sam Dekker
# Results for Sam Dekker:
#
# You searched for "Sam Dekker"
# 1 result found.
# Sam Dekker
# Results for Sam Dekker:
#
# You searched for "Jerian Grant"
# 3 results found.
# You searched for "Jerian Grant"
# 3 results found.
# You searched for "Delon Wright"
# 4 results found.
# You searched for "Delon Wright"
# 4 results found.
# You searched for "Justin Anderson"
# 1 result found.
# Justin Anderson
# Results for Justin Anderson:
#
# You searched for "Justin Anderson"
# 1 result found.
# Justin Anderson
# Results for Justin Anderson:
#
# You searched for "Bobby Portis"
# 7 results found.
# You searched for "Bobby Portis"
# 7 results found.
# You searched for "Rondae Hollis-Jefferson"
# 1 result found.
# Rondae Hollis-Jefferson
# Results for Rondae Hollis-Jefferson:
#
# You searched for "Rondae Hollis-Jefferson"
# 1 result found.
# Rondae Hollis-Jefferson
# Results for Rondae Hollis-Jefferson:
#
# You searched for "Tyus Jones"
# 17 results found.
# You searched for "Tyus Jones"
# 17 results found.
# You searched for "Jarell Martin"
# 6 results found.
# You searched for "Jarell Martin"
# 6 results found.
# You searched for "Nikola Milutinov"
# 0 results found.
# Error processing Nikola Milutinov for 2016: 'NoneType' object has no attribute 'replace'
# You searched for "Larry Nance Jr."
# 2 results found.
# Error processing Larry Nance Jr. for 2016: No tables found
# You searched for "R.J. Hunter"
# 4 results found.
# Error processing R.J. Hunter for 2016: string index out of range
# You searched for "Chris McCullough"
# 1 result found.
# Chris McCullough
# Results for Chris McCullough:
#
# You searched for "Chris McCullough"
# 1 result found.
# Chris McCullough
# Results for Chris McCullough:
#
# You searched for "Kevon Looney"
# 5 results found.
# You searched for "Kevon Looney"
# 5 results found.
# You searched for "Cedi Osman"
# 1 result found.
# Cedi Osman
# Results for Cedi Osman:
#
# Error processing Cedi Osman for 2016: string index out of range
# You searched for "Montrezl Harrell"
# 1 result found.
# Montrezl Harrell
# Results for Montrezl Harrell:
#
# You searched for "Montrezl Harrell"
# 1 result found.
# Montrezl Harrell
# Results for Montrezl Harrell:
#
# You searched for "Jordan Mickey"
# 2 results found.
# You searched for "Jordan Mickey"
# 2 results found.
# You searched for "Anthony Brown"
# 8 results found.
# You searched for "Anthony Brown"
# 8 results found.
# You searched for "Willy Hernangómez"
# 1 result found.
# Willy Hernangomez
# Results for Willy Hernangomez:
#
# Error processing Willy Hernangómez for 2016: No tables found
# You searched for "Rakeem Christmas"
# 1 result found.
# Rakeem Christmas
# Results for Rakeem Christmas:
#
# You searched for "Rakeem Christmas"
# 1 result found.
# Rakeem Christmas
# Results for Rakeem Christmas:
#
# You searched for "Richaun Holmes"
# 1 result found.
# Richaun Holmes
# Results for Richaun Holmes:
#
# You searched for "Richaun Holmes"
# 1 result found.
# Richaun Holmes
# Results for Richaun Holmes:
#
# You searched for "Darrun Hilliard"
# 1 result found.
# Darrun Hilliard
# Results for Darrun Hilliard:
#
# You searched for "Darrun Hilliard"
# 1 result found.
# Darrun Hilliard
# Results for Darrun Hilliard:
#
# You searched for "Juan Pablo Vaulet"
# 0 results found.
# Error processing Juan Pablo Vaulet for 2016: 'NoneType' object has no attribute 'replace'
# You searched for "Josh Richardson"
# 4 results found.
# You searched for "Josh Richardson"
# 4 results found.
# You searched for "Pat Connaughton"
# 1 result found.
# Pat Connaughton
# Results for Pat Connaughton:
#
# You searched for "Pat Connaughton"
# 1 result found.
# Pat Connaughton
# Results for Pat Connaughton:
#
# You searched for "Olivier Hanlan"
# 0 results found.
# Error processing Olivier Hanlan for 2016: 'NoneType' object has no attribute 'replace'
# You searched for "Joe Young"
# 13 results found.
# You searched for "Joe Young"
# 13 results found.
# You searched for "Andrew Harrison"
# 2 results found.
# Error processing Andrew Harrison for 2016: No tables found
# You searched for "Marcus Thornton"
# 2 results found.
# You searched for "Marcus Thornton"
# 2 results found.
# You searched for "Norman Powell"
# 1 result found.
# Norman Powell
# Results for Norman Powell:
#
# You searched for "Norman Powell"
# 1 result found.
# Norman Powell
# Results for Norman Powell:
#
# You searched for "Artūras Gudaitis"
# 0 results found.
# Error processing Artūras Gudaitis for 2016: 'NoneType' object has no attribute 'replace'
# You searched for "Dakari Johnson"
# 11 results found.
# Error processing Dakari Johnson for 2016: No tables found
# You searched for "Aaron White"
# 10 results found.
# Error processing Aaron White for 2016: No tables found
# You searched for "Marcus Eriksson"
# 1 result found.
# Marcus Derrickson
# Results for Marcus Derrickson:
#
# Error processing Marcus Eriksson for 2016: No tables found
# You searched for "Tyler Harvey"
# 4 results found.
# Error processing Tyler Harvey for 2016: No tables found
# You searched for "Satnam Singh"
# 0 results found.
# Error processing Satnam Singh for 2016: 'NoneType' object has no attribute 'replace'
# You searched for "Sir'Dominic Pointer"
# 0 results found.
# Error processing Sir'Dominic Pointer for 2016: 'NoneType' object has no attribute 'replace'
# You searched for "Dani Díez"
# 4 results found.
# Error processing Dani Díez for 2016: No tables found
# You searched for "Cady Lalanne"
# 0 results found.
# Error processing Cady Lalanne for 2016: 'NoneType' object has no attribute 'replace'
# You searched for "Branden Dawson"
# 3 results found.
# You searched for "Branden Dawson"
# 3 results found.
# Error processing Branden Dawson for 2017: No tables found
# You searched for "Nikola Radičević"
# 1 result found.
# Nikola Vucevic
# Results for Nikola Vucevic:
#
# You searched for "Nikola Radičević"
# 1 result found.
# Nikola Vucevic
# Results for Nikola Vucevic:
#
# You searched for "J.P. Tokoto"
# 0 results found.
# Error processing J.P. Tokoto for 2016: 'NoneType' object has no attribute 'replace'
# You searched for "Dimitrios Agravanis"
# 0 results found.
# Error processing Dimitrios Agravanis for 2016: 'NoneType' object has no attribute 'replace'
# You searched for "Luka Mitrović"
# 0 results found.
# Error processing Luka Mitrović for 2016: 'NoneType' object has no attribute 'replace'
# Results saved to 2015_player_wins_plus_minus.xlsx

# %% [markdown]
# # 2016 class

# %%
from basketball_reference_scraper.players import get_game_logs
import pandas as pd

def is_numeric(value):
    try:
        float(value)
        return True
    except ValueError:
        return False

# List of players
players = [
    "Ben Simmons",
    "Brandon Ingram",
    "Jaylen Brown",
    "Dragan Bender",
    "Kris Dunn",
    "Buddy Hield",
    "Jamal Murray",
    "Marquese Chriss",
    "Jakob Poeltl",
    "Thon Maker",
    "Domantas Sabonis",
    "Taurean Prince",
    "Georgios Papagiannis",
    "Denzel Valentine",
    "Juancho Hernangómez",
    "Guerschon Yabusele",
    "Wade Baldwin",
    "Henry Ellenson",
    "Malik Beasley",
    "Caris LeVert",
    "DeAndre' Bembry",
    "Malachi Richardson",
    "Ante Žižić",
    "Timothé Luwawu-Cabarrot",
    "Brice Johnson",
    "Furkan Korkmaz",
    "Pascal Siakam",
    "Skal Labissière",
    "Dejounte Murray",
    "Damian Jones",
    "Deyonta Davis",
    "Ivica Zubac",
    "Cheick Diallo",
    "Tyler Ulis",
    "Rade Zagorac",
    "Malcolm Brogdon",
    "Chinanu Onuaku",
    "Patrick McCaw",
    "David Michineau",
    "Diamond Stone",
    "Stephen Zimmerman",
    "Isaiah Whitehead",
    "Zhou Qi",
    "Isaïa Cordinier",
    "Demetrius Jackson",
    "A.J. Hammons",
    "Jake Layman",
    "Paul Zipser",
    "Michael Gbinije",
    "Georges Niang",
    "Ben Bentil",
    "Joel Bolomboy",
    "Petr Cornelie",
    "Kay Felder",
    "Marcus Paige",
    "Daniel Hamilton",
    "Wang Zhelin",
    "Abdel Nader",
    "Isaiah Cousins",
    "Tyrone Wallace"
]



# Dictionaries to store total wins and total +/-
player_data = []

# Loop through each player to calculate total wins and cumulative +/-
for player in players:
    total_wins = 0
    total_plus_minus = 0
    data_missing = False  # Flag for missing data
    for year in [2017, 2018]:
        try:
            # Fetch game logs
            df = get_game_logs(player, year)
            # Calculate wins where PF is numeric and RESULT starts with 'W'
            wins = df[df['PF'].apply(is_numeric) & df['RESULT'].str.startswith('W')].shape[0]
            total_wins += wins
            
            # Ensure +/- column is numeric and calculate the sum
            df['+/-'] = pd.to_numeric(df['+/-'], errors='coerce')  # Convert +/- to numeric
            total_plus_minus += df['+/-'].sum(skipna=True)  # Add the sum for the year
        except Exception as e:
            print(f"Error processing {player} for {year}: {e}")
            data_missing = True
            break  # Exit the loop for this player if data is missing

    # Append data for the player
    if data_missing:
        player_data.append({
            'Player': player,
            'Wins': None,
            'Total +/-': None
        })
    else:
        player_data.append({
            'Player': player,
            'Wins': total_wins,
            'Total +/-': total_plus_minus
        })

# Create a DataFrame for the results
results_df = pd.DataFrame(player_data)

# Save the DataFrame to an Excel file
output_file = '2016_player_wins_plus_minus.xlsx'
results_df.to_excel(output_file, index=False)
print(f"Results saved to {output_file}")
# Out:
# You searched for "Ben Simmons"
# 4 results found.
# You searched for "Ben Simmons"
# 4 results found.
# You searched for "Brandon Ingram"
# 4 results found.
# You searched for "Brandon Ingram"
# 4 results found.
# You searched for "Jaylen Brown"
# 10 results found.
# You searched for "Jaylen Brown"
# 10 results found.
# You searched for "Dragan Bender"
# 1 result found.
# Dragan Bender
# Results for Dragan Bender:
#
# You searched for "Dragan Bender"
# 1 result found.
# Dragan Bender
# Results for Dragan Bender:
#
# You searched for "Kris Dunn"
# 6 results found.
# You searched for "Kris Dunn"
# 6 results found.
# You searched for "Buddy Hield"
# 1 result found.
# Buddy Hield
# Results for Buddy Hield:
#
# You searched for "Buddy Hield"
# 1 result found.
# Buddy Hield
# Results for Buddy Hield:
#
# You searched for "Jamal Murray"
# 3 results found.
# You searched for "Jamal Murray"
# 3 results found.
# You searched for "Marquese Chriss"
# 1 result found.
# Marquese Chriss
# Results for Marquese Chriss:
#
# You searched for "Marquese Chriss"
# 1 result found.
# Marquese Chriss
# Results for Marquese Chriss:
#
# You searched for "Jakob Poeltl"
# 1 result found.
# Jakob Poeltl
# Results for Jakob Poeltl:
#
# You searched for "Jakob Poeltl"
# 1 result found.
# Jakob Poeltl
# Results for Jakob Poeltl:
#
# You searched for "Thon Maker"
# 8 results found.
# You searched for "Thon Maker"
# 8 results found.
# You searched for "Domantas Sabonis"
# 1 result found.
# Domantas Sabonis
# Results for Domantas Sabonis:
#
# You searched for "Domantas Sabonis"
# 1 result found.
# Domantas Sabonis
# Results for Domantas Sabonis:
#
# You searched for "Taurean Prince"
# 3 results found.
# You searched for "Taurean Prince"
# 3 results found.
# You searched for "Georgios Papagiannis"
# 1 result found.
# Georgios Papagiannis
# Results for Georgios Papagiannis:
#
# You searched for "Georgios Papagiannis"
# 1 result found.
# Georgios Papagiannis
# Results for Georgios Papagiannis:
#
# You searched for "Denzel Valentine"
# 2 results found.
# You searched for "Denzel Valentine"
# 2 results found.
# You searched for "Juancho Hernangómez"
# 1 result found.
# Juan Hernangomez
# Results for Juan Hernangomez:
#
# Error processing Juancho Hernangómez for 2017: 'NoneType' object has no attribute 'replace'
# You searched for "Guerschon Yabusele"
# 1 result found.
# Guerschon Yabusele
# Results for Guerschon Yabusele:
#
# Error processing Guerschon Yabusele for 2017: No tables found
# You searched for "Wade Baldwin"
# 1 result found.
# Wade Baldwin
# Results for Wade Baldwin:
#
# You searched for "Wade Baldwin"
# 1 result found.
# Wade Baldwin
# Results for Wade Baldwin:
#
# You searched for "Henry Ellenson"
# 1 result found.
# Henry Ellenson
# Results for Henry Ellenson:
#
# You searched for "Henry Ellenson"
# 1 result found.
# Henry Ellenson
# Results for Henry Ellenson:
#
# You searched for "Malik Beasley"
# 3 results found.
# You searched for "Malik Beasley"
# 3 results found.
# You searched for "Caris LeVert"
# 2 results found.
# You searched for "Caris LeVert"
# 2 results found.
# You searched for "DeAndre' Bembry"
# 1 result found.
# DeAndre' Bembry
# Results for DeAndre' Bembry:
#
# You searched for "DeAndre' Bembry"
# 1 result found.
# DeAndre' Bembry
# Results for DeAndre' Bembry:
#
# You searched for "Malachi Richardson"
# 1 result found.
# Malachi Richardson
# Results for Malachi Richardson:
#
# You searched for "Malachi Richardson"
# 1 result found.
# Malachi Richardson
# Results for Malachi Richardson:
#
# You searched for "Ante Žižić"
# 1 result found.
# Ante Zizic
# Results for Ante Zizic:
#
# Error processing Ante Žižić for 2017: No tables found
# You searched for "Timothé Luwawu-Cabarrot"
# 1 result found.
# Timothe Luwawu-Cabarrot
# Results for Timothe Luwawu-Cabarrot:
#
# You searched for "Timothé Luwawu-Cabarrot"
# 1 result found.
# Timothe Luwawu-Cabarrot
# Results for Timothe Luwawu-Cabarrot:
#
# You searched for "Brice Johnson"
# 26 results found.
# You searched for "Brice Johnson"
# 26 results found.
# You searched for "Furkan Korkmaz"
# 1 result found.
# Furkan Korkmaz
# Results for Furkan Korkmaz:
#
# Error processing Furkan Korkmaz for 2017: No tables found
# You searched for "Pascal Siakam"
# 1 result found.
# Pascal Siakam
# Results for Pascal Siakam:
#
# You searched for "Pascal Siakam"
# 1 result found.
# Pascal Siakam
# Results for Pascal Siakam:
#
# You searched for "Skal Labissière"
# 1 result found.
# Skal Labissiere
# Results for Skal Labissiere:
#
# You searched for "Skal Labissière"
# 1 result found.
# Skal Labissiere
# Results for Skal Labissiere:
#
# You searched for "Dejounte Murray"
# 1 result found.
# Dejounte Murray
# Results for Dejounte Murray:
#
# You searched for "Dejounte Murray"
# 1 result found.
# Dejounte Murray
# Results for Dejounte Murray:
#
# You searched for "Damian Jones"
# 14 results found.
# You searched for "Damian Jones"
# 14 results found.
# You searched for "Deyonta Davis"
# 2 results found.
# You searched for "Deyonta Davis"
# 2 results found.
# You searched for "Ivica Zubac"
# 1 result found.
# Ivica Zubac
# Results for Ivica Zubac:
#
# You searched for "Ivica Zubac"
# 1 result found.
# Ivica Zubac
# Results for Ivica Zubac:
#
# You searched for "Cheick Diallo"
# 1 result found.
# Cheick Diallo
# Results for Cheick Diallo:
#
# You searched for "Cheick Diallo"
# 1 result found.
# Cheick Diallo
# Results for Cheick Diallo:
#
# You searched for "Tyler Ulis"
# 5 results found.
# You searched for "Tyler Ulis"
# 5 results found.
# You searched for "Rade Zagorac"
# 0 results found.
# Error processing Rade Zagorac for 2017: 'NoneType' object has no attribute 'replace'
# You searched for "Malcolm Brogdon"
# 1 result found.
# Malcolm Brogdon
# Results for Malcolm Brogdon:
#
# You searched for "Malcolm Brogdon"
# 1 result found.
# Malcolm Brogdon
# Results for Malcolm Brogdon:
#
# You searched for "Chinanu Onuaku"
# 1 result found.
# Chinanu Onuaku
# Results for Chinanu Onuaku:
#
# You searched for "Chinanu Onuaku"
# 1 result found.
# Chinanu Onuaku
# Results for Chinanu Onuaku:
#
# You searched for "Patrick McCaw"
# 1 result found.
# Patrick McCaw
# Results for Patrick McCaw:
#
# You searched for "Patrick McCaw"
# 1 result found.
# Patrick McCaw
# Results for Patrick McCaw:
#
# You searched for "David Michineau"
# 0 results found.
# Error processing David Michineau for 2017: 'NoneType' object has no attribute 'replace'
# You searched for "Diamond Stone"
# 2 results found.
# You searched for "Diamond Stone"
# 2 results found.
# Error processing Diamond Stone for 2018: No tables found
# You searched for "Stephen Zimmerman"
# 1 result found.
# Stephen Zimmerman
# Results for Stephen Zimmerman:
#
# You searched for "Stephen Zimmerman"
# 1 result found.
# Stephen Zimmerman
# Results for Stephen Zimmerman:
#
# Error processing Stephen Zimmerman for 2018: No tables found
# You searched for "Isaiah Whitehead"
# 1 result found.
# Isaiah Whitehead
# Results for Isaiah Whitehead:
#
# You searched for "Isaiah Whitehead"
# 1 result found.
# Isaiah Whitehead
# Results for Isaiah Whitehead:
#
# You searched for "Zhou Qi"
# 1 result found.
# Zhou Qi
# Results for Zhou Qi:
#
# Error processing Zhou Qi for 2017: No tables found
# You searched for "Isaïa Cordinier"
# 0 results found.
# Error processing Isaïa Cordinier for 2017: 'NoneType' object has no attribute 'replace'
# You searched for "Demetrius Jackson"
# 1 result found.
# Demetrius Jackson
# Results for Demetrius Jackson:
#
# You searched for "Demetrius Jackson"
# 1 result found.
# Demetrius Jackson
# Results for Demetrius Jackson:
#
# You searched for "A.J. Hammons"
# 2 results found.
# Error processing A.J. Hammons for 2017: string index out of range
# You searched for "Jake Layman"
# 2 results found.
# You searched for "Jake Layman"
# 2 results found.
# You searched for "Paul Zipser"
# 3 results found.
# You searched for "Paul Zipser"
# 3 results found.
# You searched for "Michael Gbinije"
# 2 results found.
# You searched for "Michael Gbinije"
# 2 results found.
# Error processing Michael Gbinije for 2018: No tables found
# You searched for "Georges Niang"
# 4 results found.
# You searched for "Georges Niang"
# 4 results found.
# You searched for "Ben Bentil"
# 2 results found.
# You searched for "Ben Bentil"
# 2 results found.
# Error processing Ben Bentil for 2018: No tables found
# You searched for "Joel Bolomboy"
# 1 result found.
# Joel Bolomboy
# Results for Joel Bolomboy:
#
# You searched for "Joel Bolomboy"
# 1 result found.
# Joel Bolomboy
# Results for Joel Bolomboy:
#
# You searched for "Petr Cornelie"
# 0 results found.
# Error processing Petr Cornelie for 2017: 'NoneType' object has no attribute 'replace'
# You searched for "Kay Felder"
# 6 results found.
# You searched for "Kay Felder"
# 6 results found.
# You searched for "Marcus Paige"
# 6 results found.
# Error processing Marcus Paige for 2017: No tables found
# You searched for "Daniel Hamilton"
# 4 results found.
# Error processing Daniel Hamilton for 2017: No tables found
# You searched for "Wang Zhelin"
# 1 result found.
# Wang Zhizhi
# Results for Wang Zhizhi:
#
# Error processing Wang Zhelin for 2017: No tables found
# You searched for "Abdel Nader"
# 1 result found.
# Abdel Nader
# Results for Abdel Nader:
#
# Error processing Abdel Nader for 2017: No tables found
# You searched for "Isaiah Cousins"
# 1 result found.
# Isaiah Morris
# Results for Isaiah Morris:
#
# Error processing Isaiah Cousins for 2017: No tables found
# You searched for "Tyrone Wallace"
# 1 result found.
# Tyrone Wallace
# Results for Tyrone Wallace:
#
# Error processing Tyrone Wallace for 2017: No tables found
# Results saved to 2016_player_wins_plus_minus.xlsx

# %% [markdown]
# # 2017 Class

# %%
from basketball_reference_scraper.players import get_game_logs
import pandas as pd

def is_numeric(value):
    try:
        float(value)
        return True
    except ValueError:
        return False

# List of players
players = [
    "Markelle Fultz",
    "Lonzo Ball",
    "Jayson Tatum",
    "Josh Jackson",
    "De'Aaron Fox",
    "Jonathan Isaac",
    "Lauri Markkanen",
    "Frank Ntilikina",
    "Dennis Smith Jr.",
    "Zach Collins",
    "Malik Monk",
    "Luke Kennard",
    "Donovan Mitchell",
    "Bam Adebayo",
    "Justin Jackson",
    "Justin Patton",
    "D.J. Wilson",
    "T.J. Leaf",
    "John Collins",
    "Harry Giles",
    "Terrance Ferguson",
    "Jarrett Allen",
    "OG Anunoby",
    "Tyler Lydon",
    "Anžejs Pasečņiks",
    "Caleb Swanigan",
    "Kyle Kuzma",
    "Tony Bradley",
    "Derrick White",
    "Josh Hart",
    "Frank Jackson",
    "Davon Reed",
    "Wes Iwundu",
    "Frank Mason III",
    "Ivan Rabb",
    "Jonah Bolden",
    "Semi Ojeleye",
    "Jordan Bell",
    "Jawun Evans",
    "Dwayne Bacon",
    "Tyler Dorsey",
    "Thomas Bryant",
    "Isaiah Hartenstein",
    "Damyean Dotson",
    "Dillon Brooks",
    "Sterling Brown",
    "Ike Anigbogu",
    "Sindarius Thornwell",
    "Vlatko Čančar",
    "Mathias Lessort",
    "Monte Morris",
    "Edmond Sumner",
    "Kadeem Allen",
    "Alec Peters",
    "Nigel Williams-Goss",
    "Jabari Bird",
    "Sasha Vezenkov",
    "Ognjen Jaramaz",
    "Jaron Blossomgame",
    "Alpha Kaba"
]




# Dictionaries to store total wins and total +/-
player_data = []

# Loop through each player to calculate total wins and cumulative +/-
for player in players:
    total_wins = 0
    total_plus_minus = 0
    data_missing = False  # Flag for missing data
    for year in [2018, 2019]:
        try:
            # Fetch game logs
            df = get_game_logs(player, year)
            # Calculate wins where PF is numeric and RESULT starts with 'W'
            wins = df[df['PF'].apply(is_numeric) & df['RESULT'].str.startswith('W')].shape[0]
            total_wins += wins
            
            # Ensure +/- column is numeric and calculate the sum
            df['+/-'] = pd.to_numeric(df['+/-'], errors='coerce')  # Convert +/- to numeric
            total_plus_minus += df['+/-'].sum(skipna=True)  # Add the sum for the year
        except Exception as e:
            print(f"Error processing {player} for {year}: {e}")
            data_missing = True
            break  # Exit the loop for this player if data is missing

    # Append data for the player
    if data_missing:
        player_data.append({
            'Player': player,
            'Wins': None,
            'Total +/-': None
        })
    else:
        player_data.append({
            'Player': player,
            'Wins': total_wins,
            'Total +/-': total_plus_minus
        })

# Create a DataFrame for the results
results_df = pd.DataFrame(player_data)

# Save the DataFrame to an Excel file
output_file = '2017_player_wins_plus_minus.xlsx'
results_df.to_excel(output_file, index=False)
print(f"Results saved to {output_file}")
# Out:
# You searched for "Markelle Fultz"
# 1 result found.
# Markelle Fultz
# Results for Markelle Fultz:
#
# You searched for "Markelle Fultz"
# 1 result found.
# Markelle Fultz
# Results for Markelle Fultz:
#
# You searched for "Lonzo Ball"
# 4 results found.
# You searched for "Lonzo Ball"
# 4 results found.
# You searched for "Jayson Tatum"
# 1 result found.
# Jayson Tatum
# Results for Jayson Tatum:
#
# You searched for "Jayson Tatum"
# 1 result found.
# Jayson Tatum
# Results for Jayson Tatum:
#
# You searched for "Josh Jackson"
# 18 results found.
# You searched for "Josh Jackson"
# 18 results found.
# You searched for "De'Aaron Fox"
# 1 result found.
# De'Aaron Fox
# Results for De'Aaron Fox:
#
# You searched for "De'Aaron Fox"
# 1 result found.
# De'Aaron Fox
# Results for De'Aaron Fox:
#
# You searched for "Jonathan Isaac"
# 2 results found.
# You searched for "Jonathan Isaac"
# 2 results found.
# You searched for "Lauri Markkanen"
# 1 result found.
# Lauri Markkanen
# Results for Lauri Markkanen:
#
# You searched for "Lauri Markkanen"
# 1 result found.
# Lauri Markkanen
# Results for Lauri Markkanen:
#
# You searched for "Frank Ntilikina"
# 1 result found.
# Frank Ntilikina
# Results for Frank Ntilikina:
#
# Error processing Frank Ntilikina for 2018: string index out of range
# You searched for "Dennis Smith Jr."
# 1 result found.
# Dennis Smith
# Results for Dennis Smith:
#
# You searched for "Dennis Smith Jr."
# 1 result found.
# Dennis Smith
# Results for Dennis Smith:
#
# You searched for "Zach Collins"
# 9 results found.
# You searched for "Zach Collins"
# 9 results found.
# You searched for "Malik Monk"
# 5 results found.
# You searched for "Malik Monk"
# 5 results found.
# You searched for "Luke Kennard"
# 1 result found.
# Luke Kennard
# Results for Luke Kennard:
#
# You searched for "Luke Kennard"
# 1 result found.
# Luke Kennard
# Results for Luke Kennard:
#
# You searched for "Donovan Mitchell"
# 1 result found.
# Donovan Mitchell
# Results for Donovan Mitchell:
#
# You searched for "Donovan Mitchell"
# 1 result found.
# Donovan Mitchell
# Results for Donovan Mitchell:
#
# You searched for "Bam Adebayo"
# 1 result found.
# Bam Adebayo
# Results for Bam Adebayo:
#
# You searched for "Bam Adebayo"
# 1 result found.
# Bam Adebayo
# Results for Bam Adebayo:
#
# You searched for "Justin Jackson"
# 8 results found.
# You searched for "Justin Jackson"
# 8 results found.
# You searched for "Justin Patton"
# 4 results found.
# You searched for "Justin Patton"
# 4 results found.
# You searched for "D.J. Wilson"
# 7 results found.
# Error processing D.J. Wilson for 2018: string index out of range
# You searched for "T.J. Leaf"
# 5 results found.
# Error processing T.J. Leaf for 2018: string index out of range
# You searched for "John Collins"
# 17 results found.
# You searched for "John Collins"
# 17 results found.
# You searched for "Harry Giles"
# 15 results found.
# You searched for "Harry Giles"
# 15 results found.
# You searched for "Terrance Ferguson"
# 1 result found.
# Terrance Ferguson
# Results for Terrance Ferguson:
#
# You searched for "Terrance Ferguson"
# 1 result found.
# Terrance Ferguson
# Results for Terrance Ferguson:
#
# You searched for "Jarrett Allen"
# 2 results found.
# You searched for "Jarrett Allen"
# 2 results found.
# You searched for "OG Anunoby"
# 1 result found.
# OG Anunoby
# Results for OG Anunoby:
#
# You searched for "OG Anunoby"
# 1 result found.
# OG Anunoby
# Results for OG Anunoby:
#
# You searched for "Tyler Lydon"
# 3 results found.
# You searched for "Tyler Lydon"
# 3 results found.
# You searched for "Anžejs Pasečņiks"
# 1 result found.
# Anzejs Pasecniks
# Results for Anzejs Pasecniks:
#
# Error processing Anžejs Pasečņiks for 2018: No tables found
# You searched for "Caleb Swanigan"
# 1 result found.
# Caleb Swanigan
# Results for Caleb Swanigan:
#
# You searched for "Caleb Swanigan"
# 1 result found.
# Caleb Swanigan
# Results for Caleb Swanigan:
#
# You searched for "Kyle Kuzma"
# 3 results found.
# You searched for "Kyle Kuzma"
# 3 results found.
# You searched for "Tony Bradley"
# 10 results found.
# You searched for "Tony Bradley"
# 10 results found.
# You searched for "Derrick White"
# 6 results found.
# You searched for "Derrick White"
# 6 results found.
# You searched for "Josh Hart"
# 9 results found.
# You searched for "Josh Hart"
# 9 results found.
# You searched for "Frank Jackson"
# 15 results found.
# You searched for "Frank Jackson"
# 15 results found.
# You searched for "Davon Reed"
# 9 results found.
# You searched for "Davon Reed"
# 9 results found.
# You searched for "Wes Iwundu"
# 1 result found.
# Wesley Iwundu
# Results for Wesley Iwundu:
#
# Error processing Wes Iwundu for 2018: 'NoneType' object has no attribute 'replace'
# You searched for "Frank Mason III"
# 1 result found.
# Frank Mason
# Results for Frank Mason:
#
# You searched for "Frank Mason III"
# 1 result found.
# Frank Mason
# Results for Frank Mason:
#
# You searched for "Ivan Rabb"
# 2 results found.
# You searched for "Ivan Rabb"
# 2 results found.
# You searched for "Jonah Bolden"
# 2 results found.
# Error processing Jonah Bolden for 2018: No tables found
# You searched for "Semi Ojeleye"
# 1 result found.
# Semi Ojeleye
# Results for Semi Ojeleye:
#
# You searched for "Semi Ojeleye"
# 1 result found.
# Semi Ojeleye
# Results for Semi Ojeleye:
#
# You searched for "Jordan Bell"
# 10 results found.
# You searched for "Jordan Bell"
# 10 results found.
# You searched for "Jawun Evans"
# 4 results found.
# You searched for "Jawun Evans"
# 4 results found.
# You searched for "Dwayne Bacon"
# 4 results found.
# You searched for "Dwayne Bacon"
# 4 results found.
# You searched for "Tyler Dorsey"
# 3 results found.
# You searched for "Tyler Dorsey"
# 3 results found.
# You searched for "Thomas Bryant"
# 2 results found.
# You searched for "Thomas Bryant"
# 2 results found.
# You searched for "Isaiah Hartenstein"
# 1 result found.
# Isaiah Hartenstein
# Results for Isaiah Hartenstein:
#
# Error processing Isaiah Hartenstein for 2018: No tables found
# You searched for "Damyean Dotson"
# 1 result found.
# Damyean Dotson
# Results for Damyean Dotson:
#
# You searched for "Damyean Dotson"
# 1 result found.
# Damyean Dotson
# Results for Damyean Dotson:
#
# You searched for "Dillon Brooks"
# 2 results found.
# You searched for "Dillon Brooks"
# 2 results found.
# You searched for "Sterling Brown"
# 1 result found.
# Sterling Brown
# Results for Sterling Brown:
#
# You searched for "Sterling Brown"
# 1 result found.
# Sterling Brown
# Results for Sterling Brown:
#
# You searched for "Ike Anigbogu"
# 2 results found.
# You searched for "Ike Anigbogu"
# 2 results found.
# You searched for "Sindarius Thornwell"
# 1 result found.
# Sindarius Thornwell
# Results for Sindarius Thornwell:
#
# You searched for "Sindarius Thornwell"
# 1 result found.
# Sindarius Thornwell
# Results for Sindarius Thornwell:
#
# You searched for "Vlatko Čančar"
# 1 result found.
# Vlatko Cancar
# Results for Vlatko Cancar:
#
# Error processing Vlatko Čančar for 2018: No tables found
# You searched for "Mathias Lessort"
# 0 results found.
# Error processing Mathias Lessort for 2018: 'NoneType' object has no attribute 'replace'
# You searched for "Monte Morris"
# 2 results found.
# You searched for "Monte Morris"
# 2 results found.
# You searched for "Edmond Sumner"
# 1 result found.
# Edmond Sumner
# Results for Edmond Sumner:
#
# You searched for "Edmond Sumner"
# 1 result found.
# Edmond Sumner
# Results for Edmond Sumner:
#
# You searched for "Kadeem Allen"
# 1 result found.
# Kadeem Allen
# Results for Kadeem Allen:
#
# You searched for "Kadeem Allen"
# 1 result found.
# Kadeem Allen
# Results for Kadeem Allen:
#
# You searched for "Alec Peters"
# 2 results found.
# You searched for "Alec Peters"
# 2 results found.
# Error processing Alec Peters for 2019: No tables found
# You searched for "Nigel Williams-Goss"
# 1 result found.
# Nigel Williams-Goss
# Results for Nigel Williams-Goss:
#
# Error processing Nigel Williams-Goss for 2018: No tables found
# You searched for "Jabari Bird"
# 5 results found.
# You searched for "Jabari Bird"
# 5 results found.
# You searched for "Sasha Vezenkov"
# 0 results found.
# Error processing Sasha Vezenkov for 2018: 'NoneType' object has no attribute 'replace'
# You searched for "Ognjen Jaramaz"
# 0 results found.
# Error processing Ognjen Jaramaz for 2018: 'NoneType' object has no attribute 'replace'
# You searched for "Jaron Blossomgame"
# 1 result found.
# Jaron Blossomgame
# Results for Jaron Blossomgame:
#
# Error processing Jaron Blossomgame for 2018: No tables found
# You searched for "Alpha Kaba"
# 0 results found.
# Error processing Alpha Kaba for 2018: 'NoneType' object has no attribute 'replace'
# Results saved to 2017_player_wins_plus_minus.xlsx

# %% [markdown]
# # 2018 Class

# %%
from basketball_reference_scraper.players import get_game_logs
import pandas as pd

def is_numeric(value):
    try:
        float(value)
        return True
    except ValueError:
        return False

# List of players
players = [
    "Deandre Ayton",
    "Marvin Bagley III",
    "Luka Dončić",
    "Jaren Jackson Jr.",
    "Trae Young",
    "Mo Bamba",
    "Wendell Carter Jr.",
    "Collin Sexton",
    "Kevin Knox",
    "Mikal Bridges",
    "Shai Gilgeous-Alexander",
    "Miles Bridges",
    "Jerome Robinson",
    "Michael Porter Jr.",
    "Troy Brown Jr.",
    "Zhaire Smith",
    "Donte DiVincenzo",
    "Lonnie Walker IV",
    "Kevin Huerter",
    "Josh Okogie",
    "Grayson Allen",
    "Chandler Hutchison",
    "Aaron Holiday",
    "Anfernee Simons",
    "Moritz Wagner",
    "Landry Shamet",
    "Robert Williams",
    "Jacob Evans",
    "Džanan Musa",
    "Omari Spellman",
    "Elie Okobo",
    "Jevon Carter",
    "Jalen Brunson",
    "Devonte' Graham",
    "Melvin Frazier",
    "Mitchell Robinson",
    "Gary Trent Jr.",
    "Khyri Thomas",
    "Isaac Bonga",
    "Rodions Kurucs",
    "Jarred Vanderbilt",
    "Bruce Brown",
    "Justin Jackson",
    "Issuf Sanon",
    "Hamidou Diallo",
    "De'Anthony Melton",
    "Svi Mykhailiuk",
    "Keita Bates-Diop",
    "Chimezie Metu",
    "Alize Johnson",
    "Tony Carr",
    "Vince Edwards",
    "Devon Hall",
    "Shake Milton",
    "Arnoldas Kulboka",
    "Ray Spalding",
    "Kevin Hervey",
    "Thomas Welsh",
    "George King",
    "Kostas Antetokounmpo"
]





# Dictionaries to store total wins and total +/-
player_data = []

# Loop through each player to calculate total wins and cumulative +/-
for player in players:
    total_wins = 0
    total_plus_minus = 0
    data_missing = False  # Flag for missing data
    for year in [2019, 2020]:
        try:
            # Fetch game logs
            df = get_game_logs(player, year)
            # Calculate wins where PF is numeric and RESULT starts with 'W'
            wins = df[df['PF'].apply(is_numeric) & df['RESULT'].str.startswith('W')].shape[0]
            total_wins += wins
            
            # Ensure +/- column is numeric and calculate the sum
            df['+/-'] = pd.to_numeric(df['+/-'], errors='coerce')  # Convert +/- to numeric
            total_plus_minus += df['+/-'].sum(skipna=True)  # Add the sum for the year
        except Exception as e:
            print(f"Error processing {player} for {year}: {e}")
            data_missing = True
            break  # Exit the loop for this player if data is missing

    # Append data for the player
    if data_missing:
        player_data.append({
            'Player': player,
            'Wins': None,
            'Total +/-': None
        })
    else:
        player_data.append({
            'Player': player,
            'Wins': total_wins,
            'Total +/-': total_plus_minus
        })

# Create a DataFrame for the results
results_df = pd.DataFrame(player_data)

# Save the DataFrame to an Excel file
output_file = '2018_player_wins_plus_minus.xlsx'
results_df.to_excel(output_file, index=False)
print(f"Results saved to {output_file}")
# Out:
# You searched for "Deandre Ayton"
# 1 result found.
# Deandre Ayton
# Results for Deandre Ayton:
#
# You searched for "Deandre Ayton"
# 1 result found.
# Deandre Ayton
# Results for Deandre Ayton:
#
# You searched for "Marvin Bagley III"
# 1 result found.
# Marvin Bagley
# Results for Marvin Bagley:
#
# You searched for "Marvin Bagley III"
# 1 result found.
# Marvin Bagley
# Results for Marvin Bagley:
#
# You searched for "Luka Dončić"
# 1 result found.
# Luka Doncic
# Results for Luka Doncic:
#
# You searched for "Luka Dončić"
# 1 result found.
# Luka Doncic
# Results for Luka Doncic:
#
# You searched for "Jaren Jackson Jr."
# 2 results found.
# Error processing Jaren Jackson Jr. for 2019: No tables found
# You searched for "Trae Young"
# 8 results found.
# You searched for "Trae Young"
# 8 results found.
# You searched for "Mo Bamba"
# 2 results found.
# Error processing Mo Bamba for 2019: No tables found
# You searched for "Wendell Carter Jr."
# 1 result found.
# Wendell Carter
# Results for Wendell Carter:
#
# You searched for "Wendell Carter Jr."
# 1 result found.
# Wendell Carter
# Results for Wendell Carter:
#
# You searched for "Collin Sexton"
# 1 result found.
# Collin Sexton
# Results for Collin Sexton:
#
# You searched for "Collin Sexton"
# 1 result found.
# Collin Sexton
# Results for Collin Sexton:
#
# You searched for "Kevin Knox"
# 5 results found.
# You searched for "Kevin Knox"
# 5 results found.
# You searched for "Mikal Bridges"
# 3 results found.
# You searched for "Mikal Bridges"
# 3 results found.
# You searched for "Shai Gilgeous-Alexander"
# 1 result found.
# Shai Gilgeous-Alexander
# Results for Shai Gilgeous-Alexander:
#
# You searched for "Shai Gilgeous-Alexander"
# 1 result found.
# Shai Gilgeous-Alexander
# Results for Shai Gilgeous-Alexander:
#
# You searched for "Miles Bridges"
# 3 results found.
# You searched for "Miles Bridges"
# 3 results found.
# You searched for "Jerome Robinson"
# 5 results found.
# You searched for "Jerome Robinson"
# 5 results found.
# You searched for "Michael Porter Jr."
# 1 result found.
# Michael Porter
# Results for Michael Porter:
#
# You searched for "Michael Porter Jr."
# 1 result found.
# Michael Porter
# Results for Michael Porter:
#
# You searched for "Troy Brown Jr."
# 1 result found.
# Troy Brown
# Results for Troy Brown:
#
# You searched for "Troy Brown Jr."
# 1 result found.
# Troy Brown
# Results for Troy Brown:
#
# You searched for "Zhaire Smith"
# 11 results found.
# You searched for "Zhaire Smith"
# 11 results found.
# You searched for "Donte DiVincenzo"
# 1 result found.
# Donte DiVincenzo
# Results for Donte DiVincenzo:
#
# You searched for "Donte DiVincenzo"
# 1 result found.
# Donte DiVincenzo
# Results for Donte DiVincenzo:
#
# You searched for "Lonnie Walker IV"
# 1 result found.
# Lonnie Walker
# Results for Lonnie Walker:
#
# You searched for "Lonnie Walker IV"
# 1 result found.
# Lonnie Walker
# Results for Lonnie Walker:
#
# You searched for "Kevin Huerter"
# 5 results found.
# You searched for "Kevin Huerter"
# 5 results found.
# You searched for "Josh Okogie"
# 4 results found.
# You searched for "Josh Okogie"
# 4 results found.
# You searched for "Grayson Allen"
# 2 results found.
# You searched for "Grayson Allen"
# 2 results found.
# You searched for "Chandler Hutchison"
# 1 result found.
# Chandler Hutchison
# Results for Chandler Hutchison:
#
# You searched for "Chandler Hutchison"
# 1 result found.
# Chandler Hutchison
# Results for Chandler Hutchison:
#
# You searched for "Aaron Holiday"
# 2 results found.
# You searched for "Aaron Holiday"
# 2 results found.
# You searched for "Anfernee Simons"
# 1 result found.
# Anfernee Simons
# Results for Anfernee Simons:
#
# You searched for "Anfernee Simons"
# 1 result found.
# Anfernee Simons
# Results for Anfernee Simons:
#
# You searched for "Moritz Wagner"
# 2 results found.
# You searched for "Moritz Wagner"
# 2 results found.
# You searched for "Landry Shamet"
# 1 result found.
# Landry Shamet
# Results for Landry Shamet:
#
# You searched for "Landry Shamet"
# 1 result found.
# Landry Shamet
# Results for Landry Shamet:
#
# You searched for "Robert Williams"
# 7 results found.
# You searched for "Robert Williams"
# 7 results found.
# You searched for "Jacob Evans"
# 5 results found.
# You searched for "Jacob Evans"
# 5 results found.
# You searched for "Džanan Musa"
# 1 result found.
# Dzanan Musa
# Results for Dzanan Musa:
#
# You searched for "Džanan Musa"
# 1 result found.
# Dzanan Musa
# Results for Dzanan Musa:
#
# You searched for "Omari Spellman"
# 1 result found.
# Omari Spellman
# Results for Omari Spellman:
#
# You searched for "Omari Spellman"
# 1 result found.
# Omari Spellman
# Results for Omari Spellman:
#
# You searched for "Elie Okobo"
# 1 result found.
# Elie Okobo
# Results for Elie Okobo:
#
# You searched for "Elie Okobo"
# 1 result found.
# Elie Okobo
# Results for Elie Okobo:
#
# You searched for "Jevon Carter"
# 5 results found.
# You searched for "Jevon Carter"
# 5 results found.
# You searched for "Jalen Brunson"
# 1 result found.
# Jalen Brunson
# Results for Jalen Brunson:
#
# You searched for "Jalen Brunson"
# 1 result found.
# Jalen Brunson
# Results for Jalen Brunson:
#
# You searched for "Devonte' Graham"
# 1 result found.
# Devonte' Graham
# Results for Devonte' Graham:
#
# You searched for "Devonte' Graham"
# 1 result found.
# Devonte' Graham
# Results for Devonte' Graham:
#
# You searched for "Melvin Frazier"
# 1 result found.
# Melvin Frazier
# Results for Melvin Frazier:
#
# You searched for "Melvin Frazier"
# 1 result found.
# Melvin Frazier
# Results for Melvin Frazier:
#
# You searched for "Mitchell Robinson"
# 1 result found.
# Mitchell Robinson
# Results for Mitchell Robinson:
#
# You searched for "Mitchell Robinson"
# 1 result found.
# Mitchell Robinson
# Results for Mitchell Robinson:
#
# You searched for "Gary Trent Jr."
# 2 results found.
# Error processing Gary Trent Jr. for 2019: No tables found
# You searched for "Khyri Thomas"
# 6 results found.
# You searched for "Khyri Thomas"
# 6 results found.
# You searched for "Isaac Bonga"
# 2 results found.
# You searched for "Isaac Bonga"
# 2 results found.
# You searched for "Rodions Kurucs"
# 1 result found.
# Rodions Kurucs
# Results for Rodions Kurucs:
#
# You searched for "Rodions Kurucs"
# 1 result found.
# Rodions Kurucs
# Results for Rodions Kurucs:
#
# You searched for "Jarred Vanderbilt"
# 1 result found.
# Jarred Vanderbilt
# Results for Jarred Vanderbilt:
#
# You searched for "Jarred Vanderbilt"
# 1 result found.
# Jarred Vanderbilt
# Results for Jarred Vanderbilt:
#
# You searched for "Bruce Brown"
# 16 results found.
# You searched for "Bruce Brown"
# 16 results found.
# You searched for "Justin Jackson"
# 8 results found.
# You searched for "Justin Jackson"
# 8 results found.
# You searched for "Issuf Sanon"
# 0 results found.
# Error processing Issuf Sanon for 2019: 'NoneType' object has no attribute 'replace'
# You searched for "Hamidou Diallo"
# 1 result found.
# Hamidou Diallo
# Results for Hamidou Diallo:
#
# You searched for "Hamidou Diallo"
# 1 result found.
# Hamidou Diallo
# Results for Hamidou Diallo:
#
# You searched for "De'Anthony Melton"
# 1 result found.
# De'Anthony Melton
# Results for De'Anthony Melton:
#
# You searched for "De'Anthony Melton"
# 1 result found.
# De'Anthony Melton
# Results for De'Anthony Melton:
#
# You searched for "Svi Mykhailiuk"
# 0 results found.
# Error processing Svi Mykhailiuk for 2019: 'NoneType' object has no attribute 'replace'
# You searched for "Keita Bates-Diop"
# 1 result found.
# Keita Bates-Diop
# Results for Keita Bates-Diop:
#
# You searched for "Keita Bates-Diop"
# 1 result found.
# Keita Bates-Diop
# Results for Keita Bates-Diop:
#
# You searched for "Chimezie Metu"
# 1 result found.
# Chimezie Metu
# Results for Chimezie Metu:
#
# You searched for "Chimezie Metu"
# 1 result found.
# Chimezie Metu
# Results for Chimezie Metu:
#
# You searched for "Alize Johnson"
# 21 results found.
# You searched for "Alize Johnson"
# 21 results found.
# You searched for "Tony Carr"
# 17 results found.
# Error processing Tony Carr for 2019: No tables found
# You searched for "Vince Edwards"
# 5 results found.
# You searched for "Vince Edwards"
# 5 results found.
# Error processing Vince Edwards for 2020: No tables found
# You searched for "Devon Hall"
# 5 results found.
# Error processing Devon Hall for 2019: No tables found
# You searched for "Shake Milton"
# 1 result found.
# Shake Milton
# Results for Shake Milton:
#
# You searched for "Shake Milton"
# 1 result found.
# Shake Milton
# Results for Shake Milton:
#
# You searched for "Arnoldas Kulboka"
# 0 results found.
# Error processing Arnoldas Kulboka for 2019: 'NoneType' object has no attribute 'replace'
# You searched for "Ray Spalding"
# 1 result found.
# Ray Spalding
# Results for Ray Spalding:
# You searched for "Ray Spalding"
# 1 result found.
# Ray Spalding
# Results for Ray Spalding:
#
# You searched for "Kevin Hervey"
# 9 results found.
# Error processing Kevin Hervey for 2019: No tables found
# You searched for "Thomas Welsh"
# 1 result found.
# Thomas Welsh
# Results for Thomas Welsh:
#
# You searched for "Thomas Welsh"
# 1 result found.
# Thomas Welsh
# Results for Thomas Welsh:
#
# Error processing Thomas Welsh for 2020: No tables found
# You searched for "George King"
# 19 results found.
# Error processing George King for 2019: No tables found
# You searched for "Kostas Antetokounmpo"
# 1 result found.
# Kostas Antetokounmpo
# Results for Kostas Antetokounmpo:
#
# You searched for "Kostas Antetokounmpo"
# 1 result found.
# Kostas Antetokounmpo
# Results for Kostas Antetokounmpo:
#
# Results saved to 2018_player_wins_plus_minus.xlsx

# %% [markdown]
# # 2019 Class

# %%
from basketball_reference_scraper.players import get_game_logs
import pandas as pd

def is_numeric(value):
    try:
        float(value)
        return True
    except ValueError:
        return False

# List of players
players = [
    "Zion Williamson",
    "Ja Morant",
    "RJ Barrett",
    "De'Andre Hunter",
    "Darius Garland",
    "Jarrett Culver",
    "Coby White",
    "Jaxson Hayes",
    "Rui Hachimura",
    "Cam Reddish",
    "Cameron Johnson",
    "P.J. Washington",
    "Tyler Herro",
    "Romeo Langford",
    "Sekou Doumbouya",
    "Chuma Okeke",
    "Nickeil Alexander-Walker",
    "Goga Bitadze",
    "Luka Šamanić",
    "Matisse Thybulle",
    "Brandon Clarke",
    "Grant Williams",
    "Darius Bazley",
    "Ty Jerome",
    "Nassir Little",
    "Dylan Windler",
    "Mfiondu Kabengele",
    "Jordan Poole",
    "Keldon Johnson",
    "Kevin Porter Jr.",
    "Nic Claxton",
    "KZ Okpala",
    "Carsen Edwards",
    "Bruno Fernando",
    "Didi Louzada",
    "Cody Martin",
    "Deividas Sirvydis",
    "Daniel Gafford",
    "Alen Smailagić",
    "Justin James",
    "Eric Paschall",
    "Admiral Schofield",
    "Jaylen Nowell",
    "Bol Bol",
    "Isaiah Roby",
    "Talen Horton-Tucker",
    "Ignas Brazdeikis",
    "Terance Mann",
    "Quinndary Weatherspoon",
    "Jarrell Brantley",
    "Tremont Waters",
    "Jalen McDaniels",
    "Justin Wright-Foreman",
    "Marial Shayok",
    "Kyle Guy",
    "Jaylen Hands",
    "Jordan Bone",
    "Miye Oni",
    "Dewan Hernandez",
    "Vanja Marinković"
]





# Dictionaries to store total wins and total +/-
player_data = []

# Loop through each player to calculate total wins and cumulative +/-
for player in players:
    total_wins = 0
    total_plus_minus = 0
    data_missing = False  # Flag for missing data
    for year in [2020, 2021]:
        try:
            # Fetch game logs
            df = get_game_logs(player, year)
            # Calculate wins where PF is numeric and RESULT starts with 'W'
            wins = df[df['PF'].apply(is_numeric) & df['RESULT'].str.startswith('W')].shape[0]
            total_wins += wins
            
            # Ensure +/- column is numeric and calculate the sum
            df['+/-'] = pd.to_numeric(df['+/-'], errors='coerce')  # Convert +/- to numeric
            total_plus_minus += df['+/-'].sum(skipna=True)  # Add the sum for the year
        except Exception as e:
            print(f"Error processing {player} for {year}: {e}")
            data_missing = True
            break  # Exit the loop for this player if data is missing

    # Append data for the player
    if data_missing:
        player_data.append({
            'Player': player,
            'Wins': None,
            'Total +/-': None
        })
    else:
        player_data.append({
            'Player': player,
            'Wins': total_wins,
            'Total +/-': total_plus_minus
        })

# Create a DataFrame for the results
results_df = pd.DataFrame(player_data)

# Save the DataFrame to an Excel file
output_file = '2019_player_wins_plus_minus.xlsx'
results_df.to_excel(output_file, index=False)
print(f"Results saved to {output_file}")
# Out:
# You searched for "Zion Williamson"
# 5 results found.
# You searched for "Zion Williamson"
# 5 results found.
# You searched for "Ja Morant"
# 7 results found.
# You searched for "Ja Morant"
# 7 results found.
# You searched for "RJ Barrett"
# 7 results found.
# You searched for "RJ Barrett"
# 7 results found.
# You searched for "De'Andre Hunter"
# 1 result found.
# De'Andre Hunter
# Results for De'Andre Hunter:
#
# You searched for "De'Andre Hunter"
# 1 result found.
# De'Andre Hunter
# Results for De'Andre Hunter:
#
# You searched for "Darius Garland"
# 3 results found.
# You searched for "Darius Garland"
# 3 results found.
# You searched for "Jarrett Culver"
# 2 results found.
# You searched for "Jarrett Culver"
# 2 results found.
# You searched for "Coby White"
# 13 results found.
# You searched for "Coby White"
# 13 results found.
# You searched for "Jaxson Hayes"
# 3 results found.
# You searched for "Jaxson Hayes"
# 3 results found.
# You searched for "Rui Hachimura"
# 1 result found.
# Rui Hachimura
# Results for Rui Hachimura:
#
# You searched for "Rui Hachimura"
# 1 result found.
# Rui Hachimura
# Results for Rui Hachimura:
#
# You searched for "Cam Reddish"
# 1 result found.
# Cam Reddish
# Results for Cam Reddish:
#
# You searched for "Cam Reddish"
# 1 result found.
# Cam Reddish
# Results for Cam Reddish:
#
# You searched for "Cameron Johnson"
# 7 results found.
# You searched for "Cameron Johnson"
# 7 results found.
# You searched for "P.J. Washington"
# 5 results found.
# Error processing P.J. Washington for 2020: string index out of range
# You searched for "Tyler Herro"
# 4 results found.
# You searched for "Tyler Herro"
# 4 results found.
# You searched for "Romeo Langford"
# 1 result found.
# Romeo Langford
# Results for Romeo Langford:
#
# You searched for "Romeo Langford"
# 1 result found.
# Romeo Langford
# Results for Romeo Langford:
#
# You searched for "Sekou Doumbouya"
# 1 result found.
# Sekou Doumbouya
# Results for Sekou Doumbouya:
#
# You searched for "Sekou Doumbouya"
# 1 result found.
# Sekou Doumbouya
# Results for Sekou Doumbouya:
#
# You searched for "Chuma Okeke"
# 1 result found.
# Chuma Okeke
# Results for Chuma Okeke:
#
# Error processing Chuma Okeke for 2020: No tables found
# You searched for "Nickeil Alexander-Walker"
# 1 result found.
# Nickeil Alexander-Walker
# Results for Nickeil Alexander-Walker:
#
# You searched for "Nickeil Alexander-Walker"
# 1 result found.
# Nickeil Alexander-Walker
# Results for Nickeil Alexander-Walker:
#
# You searched for "Goga Bitadze"
# 1 result found.
# Goga Bitadze
# Results for Goga Bitadze:
#
# You searched for "Goga Bitadze"
# 1 result found.
# Goga Bitadze
# Results for Goga Bitadze:
#
# You searched for "Luka Šamanić"
# 1 result found.
# Luka Samanic
# Results for Luka Samanic:
#
# You searched for "Luka Šamanić"
# 1 result found.
# Luka Samanic
# Results for Luka Samanic:
#
# You searched for "Matisse Thybulle"
# 1 result found.
# Matisse Thybulle
# Results for Matisse Thybulle:
#
# You searched for "Matisse Thybulle"
# 1 result found.
# Matisse Thybulle
# Results for Matisse Thybulle:
#
# You searched for "Brandon Clarke"
# 1 result found.
# Brandon Clarke
# Results for Brandon Clarke:
#
# You searched for "Brandon Clarke"
# 1 result found.
# Brandon Clarke
# Results for Brandon Clarke:
#
# You searched for "Grant Williams"
# 34 results found.
# You searched for "Grant Williams"
# 34 results found.
# You searched for "Darius Bazley"
# 3 results found.
# You searched for "Darius Bazley"
# 3 results found.
# You searched for "Ty Jerome"
# 3 results found.
# You searched for "Ty Jerome"
# 3 results found.
# You searched for "Nassir Little"
# 1 result found.
# Nassir Little
# Results for Nassir Little:
#
# You searched for "Nassir Little"
# 1 result found.
# Nassir Little
# Results for Nassir Little:
#
# You searched for "Dylan Windler"
# 1 result found.
# Dylan Windler
# Results for Dylan Windler:
#
# You searched for "Dylan Windler"
# 1 result found.
# Dylan Windler
# Results for Dylan Windler:
#
# You searched for "Mfiondu Kabengele"
# 1 result found.
# Mfiondu Kabengele
# Results for Mfiondu Kabengele:
#
# You searched for "Mfiondu Kabengele"
# 1 result found.
# Mfiondu Kabengele
# Results for Mfiondu Kabengele:
#
# You searched for "Jordan Poole"
# 9 results found.
# You searched for "Jordan Poole"
# 9 results found.
# You searched for "Keldon Johnson"
# 12 results found.
# You searched for "Keldon Johnson"
# 12 results found.
# You searched for "Kevin Porter Jr."
# 2 results found.
# Error processing Kevin Porter Jr. for 2020: No tables found
# You searched for "Nic Claxton"
# 2 results found.
# Error processing Nic Claxton for 2020: 'NoneType' object has no attribute 'replace'
# You searched for "KZ Okpala"
# 1 result found.
# KZ Okpala
# Results for KZ Okpala:
#
# You searched for "KZ Okpala"
# 1 result found.
# KZ Okpala
# Results for KZ Okpala:
#
# You searched for "Carsen Edwards"
# 3 results found.
# You searched for "Carsen Edwards"
# 3 results found.
# You searched for "Bruno Fernando"
# 1 result found.
# Bruno Fernando
# Results for Bruno Fernando:
#
# You searched for "Bruno Fernando"
# 1 result found.
# Bruno Fernando
# Results for Bruno Fernando:
#
# You searched for "Didi Louzada"
# 0 results found.
# Error processing Didi Louzada for 2020: 'NoneType' object has no attribute 'replace'
# You searched for "Cody Martin"
# 9 results found.
# You searched for "Cody Martin"
# 9 results found.
# You searched for "Deividas Sirvydis"
# 1 result found.
# Deividas Sirvydis
# Results for Deividas Sirvydis:
#
# Error processing Deividas Sirvydis for 2020: No tables found
# You searched for "Daniel Gafford"
# 1 result found.
# Daniel Gafford
# Results for Daniel Gafford:
#
# You searched for "Daniel Gafford"
# 1 result found.
# Daniel Gafford
# Results for Daniel Gafford:
#
# You searched for "Alen Smailagić"
# 1 result found.
# Alen Smailagic
# Results for Alen Smailagic:
#
# You searched for "Alen Smailagić"
# 1 result found.
# Alen Smailagic
# Results for Alen Smailagic:
#
# You searched for "Justin James"
# 6 results found.
# You searched for "Justin James"
# 6 results found.
# You searched for "Eric Paschall"
# 1 result found.
# Eric Paschall
# Results for Eric Paschall:
#
# You searched for "Eric Paschall"
# 1 result found.
# Eric Paschall
# Results for Eric Paschall:
#
# You searched for "Admiral Schofield"
# 1 result found.
# Admiral Schofield
# Results for Admiral Schofield:
#
# You searched for "Admiral Schofield"
# 1 result found.
# Admiral Schofield
# Results for Admiral Schofield:
#
# Error processing Admiral Schofield for 2021: No tables found
# You searched for "Jaylen Nowell"
# 3 results found.
# You searched for "Jaylen Nowell"
# 3 results found.
# You searched for "Bol Bol"
# 11 results found.
# You searched for "Bol Bol"
# 11 results found.
# You searched for "Isaiah Roby"
# 3 results found.
# You searched for "Isaiah Roby"
# 3 results found.
# You searched for "Talen Horton-Tucker"
# 1 result found.
# Talen Horton-Tucker
# Results for Talen Horton-Tucker:
#
# You searched for "Talen Horton-Tucker"
# 1 result found.
# Talen Horton-Tucker
# Results for Talen Horton-Tucker:
#
# You searched for "Ignas Brazdeikis"
# 1 result found.
# Ignas Brazdeikis
# Results for Ignas Brazdeikis:
#
# You searched for "Ignas Brazdeikis"
# 1 result found.
# Ignas Brazdeikis
# Results for Ignas Brazdeikis:
#
# You searched for "Terance Mann"
# 1 result found.
# Terance Mann
# Results for Terance Mann:
#
# You searched for "Terance Mann"
# 1 result found.
# Terance Mann
# Results for Terance Mann:
#
# You searched for "Quinndary Weatherspoon"
# 1 result found.
# Quinndary Weatherspoon
# Results for Quinndary Weatherspoon:
#
# You searched for "Quinndary Weatherspoon"
# 1 result found.
# Quinndary Weatherspoon
# Results for Quinndary Weatherspoon:
#
# You searched for "Jarrell Brantley"
# 1 result found.
# Jarrell Brantley
# Results for Jarrell Brantley:
#
# You searched for "Jarrell Brantley"
# 1 result found.
# Jarrell Brantley
# Results for Jarrell Brantley:
#
# You searched for "Tremont Waters"
# 1 result found.
# Tremont Waters
# Results for Tremont Waters:
#
# You searched for "Tremont Waters"
# 1 result found.
# Tremont Waters
# Results for Tremont Waters:
#
# You searched for "Jalen McDaniels"
# 4 results found.
# You searched for "Jalen McDaniels"
# 4 results found.
# You searched for "Justin Wright-Foreman"
# 1 result found.
# Justin Wright-Foreman
# Results for Justin Wright-Foreman:
#
# You searched for "Justin Wright-Foreman"
# 1 result found.
# Justin Wright-Foreman
# Results for Justin Wright-Foreman:
#
# Error processing Justin Wright-Foreman for 2021: No tables found
# You searched for "Marial Shayok"
# 1 result found.
# Marial Shayok
# Results for Marial Shayok:
#
# You searched for "Marial Shayok"
# 1 result found.
# Marial Shayok
# Results for Marial Shayok:
# Error processing Marial Shayok for 2021: No tables found
# You searched for "Kyle Guy"
# 5 results found.
# You searched for "Kyle Guy"
# 5 results found.
# You searched for "Jaylen Hands"
# 6 results found.
# You searched for "Jaylen Hands"
# 6 results found.
# You searched for "Jordan Bone"
# 10 results found.
# You searched for "Jordan Bone"
# 10 results found.
# You searched for "Miye Oni"
# 4 results found.
# You searched for "Miye Oni"
# 4 results found.
# You searched for "Dewan Hernandez"
# 1 result found.
# Dewan Hernandez
# Results for Dewan Hernandez:
#
# You searched for "Dewan Hernandez"
# 1 result found.
# Dewan Hernandez
# Results for Dewan Hernandez:
#
# Error processing Dewan Hernandez for 2021: No tables found
# You searched for "Vanja Marinković"
# 0 results found.
# Error processing Vanja Marinković for 2020: 'NoneType' object has no attribute 'replace'
# Results saved to 2019_player_wins_plus_minus.xlsx

# %% [markdown]
# # 2020 Class

# %%
from basketball_reference_scraper.players import get_game_logs
import pandas as pd

def is_numeric(value):
    try:
        float(value)
        return True
    except ValueError:
        return False

# List of players
players = [
    "Anthony Edwards",
    "James Wiseman",
    "LaMelo Ball",
    "Patrick Williams",
    "Isaac Okoro",
    "Onyeka Okongwu",
    "Killian Hayes",
    "Obi Toppin",
    "Deni Avdija",
    "Jalen Smith",
    "Devin Vassell",
    "Tyrese Haliburton",
    "Kira Lewis Jr.",
    "Aaron Nesmith",
    "Cole Anthony",
    "Isaiah Stewart",
    "Aleksej Pokuševski",
    "Josh Green",
    "Saddiq Bey",
    "Precious Achiuwa",
    "Tyrese Maxey",
    "Zeke Nnaji",
    "Leandro Bolmaro",
    "R.J. Hampton",
    "Immanuel Quickley",
    "Payton Pritchard",
    "Udoka Azubuike",
    "Jaden McDaniels",
    "Malachi Flynn",
    "Desmond Bane",
    "Tyrell Terry",
    "Vernon Carey Jr.",
    "Daniel Oturu",
    "Théo Maledon",
    "Xavier Tillman Sr.",
    "Tyler Bey",
    "Vít Krejčí",
    "Saben Lee",
    "Elijah Hughes",
    "Robert Woodard II",
    "Tre Jones",
    "Nick Richards",
    "Jahmi'us Ramsey",
    "Marko Simonović",
    "Jordan Nwora",
    "CJ Elleby",
    "Yam Madar",
    "Nico Mannion",
    "Isaiah Joe",
    "Skylar Mays",
    "Justinian Jessup",
    "KJ Martin",
    "Cassius Winston",
    "Cassius Stanley",
    "Jay Scrubb",
    "Grant Riller",
    "Reggie Perry",
    "Paul Reed",
    "Jalen Harris",
    "Sam Merrill"
]






# Dictionaries to store total wins and total +/-
player_data = []

# Loop through each player to calculate total wins and cumulative +/-
for player in players:
    total_wins = 0
    total_plus_minus = 0
    data_missing = False  # Flag for missing data
    for year in [2021, 2022]:
        try:
            # Fetch game logs
            df = get_game_logs(player, year)
            # Calculate wins where PF is numeric and RESULT starts with 'W'
            wins = df[df['PF'].apply(is_numeric) & df['RESULT'].str.startswith('W')].shape[0]
            total_wins += wins
            
            # Ensure +/- column is numeric and calculate the sum
            df['+/-'] = pd.to_numeric(df['+/-'], errors='coerce')  # Convert +/- to numeric
            total_plus_minus += df['+/-'].sum(skipna=True)  # Add the sum for the year
        except Exception as e:
            print(f"Error processing {player} for {year}: {e}")
            data_missing = True
            break  # Exit the loop for this player if data is missing

    # Append data for the player
    if data_missing:
        player_data.append({
            'Player': player,
            'Wins': None,
            'Total +/-': None
        })
    else:
        player_data.append({
            'Player': player,
            'Wins': total_wins,
            'Total +/-': total_plus_minus
        })

# Create a DataFrame for the results
results_df = pd.DataFrame(player_data)

# Save the DataFrame to an Excel file
output_file = '2020_player_wins_plus_minus.xlsx'
results_df.to_excel(output_file, index=False)
print(f"Results saved to {output_file}")
# Out:
# You searched for "Anthony Edwards"
# 3 results found.
# You searched for "Anthony Edwards"
# 3 results found.
# You searched for "James Wiseman"
# 2 results found.
# You searched for "James Wiseman"
# 2 results found.
# You searched for "LaMelo Ball"
# 3 results found.
# You searched for "LaMelo Ball"
# 3 results found.
# You searched for "Patrick Williams"
# 4 results found.
# You searched for "Patrick Williams"
# 4 results found.
# You searched for "Isaac Okoro"
# 2 results found.
# You searched for "Isaac Okoro"
# 2 results found.
# You searched for "Onyeka Okongwu"
# 1 result found.
# Onyeka Okongwu
# Results for Onyeka Okongwu:
#
# You searched for "Onyeka Okongwu"
# 1 result found.
# Onyeka Okongwu
# Results for Onyeka Okongwu:
#
# You searched for "Killian Hayes"
# 2 results found.
# You searched for "Killian Hayes"
# 2 results found.
# You searched for "Obi Toppin"
# 1 result found.
# Obi Toppin
# Results for Obi Toppin:
#
# You searched for "Obi Toppin"
# 1 result found.
# Obi Toppin
# Results for Obi Toppin:
#
# You searched for "Deni Avdija"
# 1 result found.
# Deni Avdija
# Results for Deni Avdija:
#
# You searched for "Deni Avdija"
# 1 result found.
# Deni Avdija
# Results for Deni Avdija:
#
# You searched for "Jalen Smith"
# 33 results found.
# You searched for "Jalen Smith"
# 33 results found.
# You searched for "Devin Vassell"
# 1 result found.
# Devin Vassell
# Results for Devin Vassell:
#
# You searched for "Devin Vassell"
# 1 result found.
# Devin Vassell
# Results for Devin Vassell:
#
# You searched for "Tyrese Haliburton"
# 1 result found.
# Tyrese Haliburton
# Results for Tyrese Haliburton:
#
# You searched for "Tyrese Haliburton"
# 1 result found.
# Tyrese Haliburton
# Results for Tyrese Haliburton:
#
# You searched for "Kira Lewis Jr."
# 1 result found.
# Kira Lewis
# Results for Kira Lewis:
#
# You searched for "Kira Lewis Jr."
# 1 result found.
# Kira Lewis
# Results for Kira Lewis:
#
# You searched for "Aaron Nesmith"
# 2 results found.
# You searched for "Aaron Nesmith"
# 2 results found.
# You searched for "Cole Anthony"
# 3 results found.
# You searched for "Cole Anthony"
# 3 results found.
# You searched for "Isaiah Stewart"
# 1 result found.
# Isaiah Stewart
# Results for Isaiah Stewart:
#
# You searched for "Isaiah Stewart"
# 1 result found.
# Isaiah Stewart
# Results for Isaiah Stewart:
#
# You searched for "Aleksej Pokuševski"
# 1 result found.
# Aleksej Pokusevski
# Results for Aleksej Pokusevski:
#
# You searched for "Aleksej Pokuševski"
# 1 result found.
# Aleksej Pokusevski
# Results for Aleksej Pokusevski:
#
# You searched for "Josh Green"
# 14 results found.
# You searched for "Josh Green"
# 14 results found.
# You searched for "Saddiq Bey"
# 1 result found.
# Saddiq Bey
# Results for Saddiq Bey:
#
# You searched for "Saddiq Bey"
# 1 result found.
# Saddiq Bey
# Results for Saddiq Bey:
#
# You searched for "Precious Achiuwa"
# 1 result found.
# Precious Achiuwa
# Results for Precious Achiuwa:
#
# You searched for "Precious Achiuwa"
# 1 result found.
# Precious Achiuwa
# Results for Precious Achiuwa:
#
# You searched for "Tyrese Maxey"
# 1 result found.
# Tyrese Maxey
# Results for Tyrese Maxey:
#
# You searched for "Tyrese Maxey"
# 1 result found.
# Tyrese Maxey
# Results for Tyrese Maxey:
#
# You searched for "Zeke Nnaji"
# 1 result found.
# Zeke Nnaji
# Results for Zeke Nnaji:
#
# You searched for "Zeke Nnaji"
# 1 result found.
# Zeke Nnaji
# Results for Zeke Nnaji:
#
# You searched for "Leandro Bolmaro"
# 1 result found.
# Leandro Bolmaro
# Results for Leandro Bolmaro:
#
# Error processing Leandro Bolmaro for 2021: No tables found
# You searched for "R.J. Hampton"
# 3 results found.
# Error processing R.J. Hampton for 2021: string index out of range
# You searched for "Immanuel Quickley"
# 1 result found.
# Immanuel Quickley
# Results for Immanuel Quickley:
#
# You searched for "Immanuel Quickley"
# 1 result found.
# Immanuel Quickley
# Results for Immanuel Quickley:
#
# You searched for "Payton Pritchard"
# 1 result found.
# Payton Pritchard
# Results for Payton Pritchard:
#
# You searched for "Payton Pritchard"
# 1 result found.
# Payton Pritchard
# Results for Payton Pritchard:
#
# You searched for "Udoka Azubuike"
# 1 result found.
# Udoka Azubuike
# Results for Udoka Azubuike:
#
# You searched for "Udoka Azubuike"
# 1 result found.
# Udoka Azubuike
# Results for Udoka Azubuike:
#
# You searched for "Jaden McDaniels"
# 4 results found.
# You searched for "Jaden McDaniels"
# 4 results found.
# You searched for "Malachi Flynn"
# 1 result found.
# Malachi Flynn
# Results for Malachi Flynn:
#
# You searched for "Malachi Flynn"
# 1 result found.
# Malachi Flynn
# Results for Malachi Flynn:
#
# You searched for "Desmond Bane"
# 2 results found.
# You searched for "Desmond Bane"
# 2 results found.
# You searched for "Tyrell Terry"
# 1 result found.
# Tyrell Terry
# Results for Tyrell Terry:
#
# You searched for "Tyrell Terry"
# 1 result found.
# Tyrell Terry
# Results for Tyrell Terry:
#
# You searched for "Vernon Carey Jr."
# 1 result found.
# Vernon Carey Jr.
# Results for Vernon Carey Jr.:
#
# You searched for "Vernon Carey Jr."
# 1 result found.
# Vernon Carey Jr.
# Results for Vernon Carey Jr.:
#
# You searched for "Daniel Oturu"
# 3 results found.
# You searched for "Daniel Oturu"
# 3 results found.
# You searched for "Théo Maledon"
# 1 result found.
# Theo Maledon
# Results for Theo Maledon:
#
# You searched for "Théo Maledon"
# 1 result found.
# Theo Maledon
# Results for Theo Maledon:
#
# You searched for "Xavier Tillman Sr."
# 1 result found.
# Xavier Tillman
# Results for Xavier Tillman:
#
# You searched for "Xavier Tillman Sr."
# 1 result found.
# Xavier Tillman
# Results for Xavier Tillman:
#
# You searched for "Tyler Bey"
# 7 results found.
# You searched for "Tyler Bey"
# 7 results found.
# Error processing Tyler Bey for 2022: No tables found
# You searched for "Vít Krejčí"
# 0 results found.
# Error processing Vít Krejčí for 2021: 'NoneType' object has no attribute 'replace'
# You searched for "Saben Lee"
# 8 results found.
# You searched for "Saben Lee"
# 8 results found.
# You searched for "Elijah Hughes"
# 1 result found.
# Elijah Hughes
# Results for Elijah Hughes:
#
# You searched for "Elijah Hughes"
# 1 result found.
# Elijah Hughes
# Results for Elijah Hughes:
#
# You searched for "Robert Woodard II"
# 1 result found.
# Robert Woodard
# Results for Robert Woodard:
#
# You searched for "Robert Woodard II"
# 1 result found.
# Robert Woodard
# Results for Robert Woodard:
#
# You searched for "Tre Jones"
# 25 results found.
# You searched for "Tre Jones"
# 25 results found.
# You searched for "Nick Richards"
# 1 result found.
# Nick Richards
# Results for Nick Richards:
#
# You searched for "Nick Richards"
# 1 result found.
# Nick Richards
# Results for Nick Richards:
#
# You searched for "Jahmi'us Ramsey"
# 1 result found.
# Jahmi'us Ramsey
# Results for Jahmi'us Ramsey:
#
# You searched for "Jahmi'us Ramsey"
# 1 result found.
# Jahmi'us Ramsey
# Results for Jahmi'us Ramsey:
#
# You searched for "Marko Simonović"
# 1 result found.
# Marko Simonovic
# Results for Marko Simonovic:
#
# Error processing Marko Simonović for 2021: No tables found
# You searched for "Jordan Nwora"
# 6 results found.
# You searched for "Jordan Nwora"
# 6 results found.
# You searched for "CJ Elleby"
# 2 results found.
# You searched for "CJ Elleby"
# 2 results found.
# You searched for "Yam Madar"
# 2 results found.
# Error processing Yam Madar for 2021: No tables found
# You searched for "Nico Mannion"
# 4 results found.
# You searched for "Nico Mannion"
# 4 results found.
# Error processing Nico Mannion for 2022: No tables found
# You searched for "Isaiah Joe"
# 3 results found.
# You searched for "Isaiah Joe"
# 3 results found.
# You searched for "Skylar Mays"
# 1 result found.
# Skylar Mays
# Results for Skylar Mays:
#
# You searched for "Skylar Mays"
# 1 result found.
# Skylar Mays
# Results for Skylar Mays:
#
# You searched for "Justinian Jessup"
# 1 result found.
# Justinian Jessup
# Results for Justinian Jessup:
#
# Error processing Justinian Jessup for 2021: No tables found
# You searched for "KJ Martin"
# 9 results found.
# Error processing KJ Martin for 2021: No tables found
# You searched for "Cassius Winston"
# 1 result found.
# Cassius Winston
# Results for Cassius Winston:
#
# You searched for "Cassius Winston"
# 1 result found.
# Cassius Winston
# Results for Cassius Winston:
#
# You searched for "Cassius Stanley"
# 2 results found.
# You searched for "Cassius Stanley"
# 2 results found.
# You searched for "Jay Scrubb"
# 1 result found.
# Jay Scrubb
# Results for Jay Scrubb:
#
# You searched for "Jay Scrubb"
# 1 result found.
# Jay Scrubb
# Results for Jay Scrubb:
#
# You searched for "Grant Riller"
# 4 results found.
# You searched for "Grant Riller"
# 4 results found.
# You searched for "Reggie Perry"
# 9 results found.
# You searched for "Reggie Perry"
# 9 results found.
# You searched for "Paul Reed"
# 16 results found.
# You searched for "Paul Reed"
# 16 results found.
# You searched for "Jalen Harris"
# 15 results found.
# You searched for "Jalen Harris"
# 15 results found.
# Error processing Jalen Harris for 2022: No tables found
# You searched for "Sam Merrill"
# 4 results found.
# You searched for "Sam Merrill"
# 4 results found.
# Results saved to 2020_player_wins_plus_minus.xlsx

# %% [markdown]
# # Excel 合併

# %%
import pandas as pd
import os

folder_path = "C:\\Users\\User\\OneDrive\\桌面\\會研所\\商統\\Final_Report"

dataframes = []

for file_name in os.listdir(folder_path):
    if file_name.endswith(".xlsx"):  
        file_path = os.path.join(folder_path, file_name)
        df = pd.read_excel(file_path) 
        dataframes.append(df)  


combined_df = pd.concat(dataframes, ignore_index=True)

output_file = "combined_excel.xlsx"
combined_df.to_excel(output_file, index=False)

print(f"Combined Excel file saved as {output_file}")
# Out:
# Combined Excel file saved as combined_excel.xlsx

# %% [markdown]
# # 查詢個別球員

# %%
from basketball_reference_scraper.players import get_game_logs
import pandas as pd

def is_numeric(value):
    try:
        float(value)
        return True
    except ValueError:
        return False

player = "Anthony Davis"
total_wins = 0
total_plus_minus = 0
data_missing = False  # Flag for missing data

for year in [2021, 2022]:
    df = get_game_logs(player, year)
    # Calculate wins where PF is numeric and RESULT starts with 'W'
    wins = df[df['PF'].apply(is_numeric) & df['RESULT'].str.startswith('W')].shape[0]
    total_wins += wins

    # Ensure +/- column is numeric and calculate the sum
    df['+/-'] = pd.to_numeric(df['+/-'], errors='coerce')  # Convert +/- to numeric
    total_plus_minus += df['+/-'].sum(skipna=True)  # Add the sum for the year
    
print(f"total wins = {total_wins}, total +/- = {total_plus_minus}")
# Out:
# You searched for "Anthony Davis"
# 9 results found.
# You searched for "Anthony Davis"
# 9 results found.
# total wins = 40, total +/- = 23.0
